# %% [markdown]
# # Pytorch tutorial
#
# In this tutorial we will cover some basic concepts of optimization using [Pytorch](https://pytorch.org/) machine learning library.
#
# We will go through
# 1. introduction to pytorch
# 2. Example of using gradient descent on simple function
# 3. Define and train Neural Networks for classification task
#
#
# some usefully links
# 1. pytorch documentation: https://pytorch.org/docs/stable/
# 2. pytorch tutorials: https://pytorch.org/tutorials/beginner/basics/intro.html

# %% [markdown]
# # 1. Introduction to Pytorch
#
# Pytorch is one of the most famous libraries to develop deep learning models.
#
# We will go thought the basic concepts pytorch while we will explain more as we move forward on the tutorial.
#
# We will use Pytorch version: '2.1.0'

# %%
# you can install torch by using the following command
# !pip install torch==2.1.0

# %%
# you can install torchsummary by using the following command
# !pip install torchsummary

# %%
import torch
import numpy as np
import matplotlib.pyplot as plt

# %%
torch.__version__
# Out:
# '2.1.0'

# %% [markdown]
# # Tensors
#
# Tensors is one of the fundamental componentes of pytorch.
# You can think of tensors as a numpy arrays.
#
# Using Tensors pytorch is able to create computational graphs and calculate the gradients.
#
# Tensors support different kind of operations listed in the following [link](https://pytorch.org/docs/stable/torch.html#pointwise-ops)
# Apart from the pytorch operators we can apply python operators between tensors.

# %%
tensor_1 = torch.tensor([[1., 2.], 
                         [3., 3.]])

tensor_2 = torch.tensor([[1., 0], 
                         [-1., 0]])

# %%
print("tensor_1 shape: ", tensor_1.shape)
print("tensor_2 shape: ", tensor_2.shape)
# Out:
# tensor_1 shape:  torch.Size([2, 2])
# tensor_2 shape:  torch.Size([2, 2])

# %%
elem_mul = tensor_1 * tensor_2
print("Element wise multiplication")
print("Result shape: ", elem_mul.size())
elem_mul
# Out:
# Element wise multiplication
# Result shape:  torch.Size([2, 2])
# tensor([[ 1.,  0.],
#         [-3.,  0.]])

# %%
matrix_mul = torch.matmul(tensor_1,tensor_2)
print("Matrix multiplication")
print("Result shape: ", matrix_mul.size())
torch.matmul(tensor_1,tensor_2)
# Out:
# Matrix multiplication
# Result shape:  torch.Size([2, 2])
# tensor([[-1.,  0.],
#         [ 0.,  0.]])

# %%
# get tensor as numpy array
tensor_1.data.numpy()
# Out:
# array([[1., 2.],
#        [3., 3.]], dtype=float32)

# %% [markdown]
# To begin lets define a simple polynomial function.

# %%
def f(x):
    """
    A convex function
    f(x) = (x-5)^2
    """
    y = (x-5)**2
    return y

# %%
x = torch.linspace(-5, 15,100)

plt.figure()
plt.plot(x, f(x), label = "(x-5)^2")
plt.legend()
plt.title("Convex function \n  f(x) = (x-5)^2")
plt.ylabel("y")
plt.xlabel("x")
plt.show()
plt.close()

# %% [markdown]
# The above function has the following computational graph
#
# <p align="center">
#   <img style="float: left;" src="./figures/Computational_Graph.png" width="500"/>
# </p>

# %% [markdown]
# The libraries that implement automatic differentiation keep track of the different operation between variables to construct the computational graph.
#
# Having this graph allows us to compute the gradients of complex function.
#
#
# Having a computational graph we have two main operation:
# 1. **Forward pass**: calculate the output of the computational graph. In our example the value of f(x)
# 2. **Backward pass**: calculate the gradients of each node in the computational graph.
#    Having the gradients of each node allows us to calculate the final gradient of each node using the chain rule of differentiation.In our example the df/dx.
#
#
# <p align="center">
#   <img style="float: left;" src="./figures/Auto_diff_Computational_Graph.png" width="900"/>
# </p>

# %%
# create tensors with requires_grad = true in order to indicate pytorch to track the gradients of the tensor.
x = torch.tensor(5.0, requires_grad = True)

# get the output of a function
y = f(x) # forward pass

# Compute gradients using backward function for y
y.backward()

# Access the gradients using x.grad
gradient = x.grad
print("gradient df(x)/dx|(x=5) :", gradient.data.numpy())
# Out:
# gradient df(x)/dx|(x=5) : 0.0

# %%
def grad_f(x):
    """
    return the gradient of the function evaluated at x.
    """
    grad = 2*(x-5)
    return grad

# %%
x = 5

print("f(x=5)=",f(x))
print("Analytic Gradient df/dx|(x=5)=", grad_f(5))
# Out:
# f(x=5)= 0
# Analytic Gradient df/dx|(x=5)= 0

# %% [markdown]
# # Gradient Decent
#
# **Gradient Descent (GD)** is a iterative method to find a minimum of a **convex function**.
#
# **Gradient descent** is one of the most popular algorithms to perform optimization and by far the most common way to optimize neural networks.
#
# In machine learning, Gradient descent is a way to minimize an objective function whit respect to model’s parameters by updating the parameters in the opposite direction of the gradient of the objective function w.r.t. to the parameters.
#
# <figure>
#   <img style="float: left;" src="./figures/Gradiend_descent.png" width="800"/>
# </figure>

# %% [markdown]
# ### Implement Gradient Descent
# in the following example we will find the minimum of a function using gradient decent.
#
#
# <figure>
#   <img style="float: left;" src="./figures/sgd.png" width="400"/>
# </figure>|

# %%
x_init= -13.0
thr = 0.0001
step_max = 500
lr = 0.1
min_value = 0

function = f

def gradient_decent(function, x_init, min_value, lr, step_max, thr):
    x = torch.tensor(x_init, requires_grad = True)
    
    x_history = [x.data]
    step = 0 
    while step < step_max:
        # step 1. Forward pass to get the output
        y = function(x)

        # step 2. Backward pass to calculate the gradient
        y.backward()

        # step 3. Update x to find minimum
        gradient = x.grad.data
        x.data = x.data - lr * gradient
        x.grad.data.zero_() # tenchical steps, otherwise accumulate the gradients

        # just keep the values of x
        x_history += [x.data]
        step = step +1
        
        # stoping critiria
        if abs(function(x.data) - function(x_history[-2])) < thr:
            break
    x_history = np.array(x_history)
    return x.data, step, x_history

# %%
x_min, total_steps, x_history = gradient_decent(function = f, 
                                                x_init = -3.0 ,
                                                min_value=0,
                                                lr = 0.1,
                                                step_max = 100,
                                                thr = 0.001)

# %%
print("Total steps to achive minimum:" , total_steps)
print("Minimum:" , x_min.data.numpy())
# Out:
# Total steps to achive minimum: 24
# Minimum: 4.962221

# %%
x_history = np.array(x_history)

# %%
x = np.linspace(-13, 23,100)
# x_history = np.array()
plt.figure()
plt.plot(x, f(x), label = "(x-5)^2")
plt.plot(x_history, f(x_history),marker = "o", color="r")
plt.legend()
plt.title("Convex function")
plt.ylabel("y")
plt.xlabel("x")
plt.show()
plt.close()

# %% [markdown]
# ### lr = 0.005

# %%
x_min, total_steps, x_history = gradient_decent(function = f, 
                                                x_init = -3.0 ,
                                                min_value=0,
                                                lr = 0.005,
                                                step_max = 100,
                                                thr = 0.001)

# %%
print("Total steps to achive minimum:" , total_steps)
print("Minimum:" , x_min.data.numpy())
# Out:
# Total steps to achive minimum: 100
# Minimum: 2.071741

# %%
x = np.linspace(-13, 23,100)
# x_history = np.array()
plt.figure()
plt.plot(x, f(x), label = "(x-5)^2")
plt.plot(x_history, f(x_history),marker = "o", color="r")
plt.legend()
plt.title("Convex function")
plt.ylabel("y")
plt.xlabel("x")
plt.show()
plt.close()

# %% [markdown]
# ### lr = 0.7

# %%
x_min, total_steps, x_history = gradient_decent(function = f, 
                                                x_init = -3.0 ,
                                                min_value=0,
                                                lr = 0.7,
                                                step_max = 100,
                                                thr = 0.001)

# %%
print("Total steps to achive minimum:" , total_steps)
print("Minimum:" , x_min.data.numpy())
# Out:
# Total steps to achive minimum: 7
# Minimum: 5.0131073

# %%
x = np.linspace(-13, 23,100)
# x_history = np.array()
plt.figure()
plt.plot(x, f(x), label = "(x-5)^2")
plt.plot(x_history, f(x_history),marker = "o", color="r")
plt.legend()
plt.title("Convex function")
plt.ylabel("y")
plt.xlabel("x")
plt.show()
plt.close()

# %% [markdown]
# ### lr = 1.1

# %%
x_min, total_steps, x_history = gradient_decent(function = f, 
                                                x_init = -3.0 ,
                                                min_value=0,
                                                lr = 1.1,
                                                step_max = 5,
                                                thr = 0.001)

# %%
x = np.linspace(-13, 23,100)
# x_history = np.array()
plt.figure()
plt.plot(x, f(x), label = "(x-5)^2")
plt.plot(x_history, f(x_history),marker = "o", color="r")
plt.legend()
plt.title("Convex function")
plt.ylabel("y")
plt.xlabel("x")
plt.show()
plt.close()

# %% [markdown]
# # Load Adult dataset

# %%
from collections import OrderedDict

data_types = OrderedDict([
    ("age", "int"),
    ("workclass", "category"),
    ("final_weight", "int"),  # originally it was called fnlwgt
    ("education", "category"),
    ("education_num", "int"),
    ("marital_status", "category"),
    ("occupation", "category"),
    ("relationship", "category"),
    ("race", "category"),
    ("sex", "category"),
    ("capital_gain", "float"),  # required because of NaN values
    ("capital_loss", "int"),
    ("hours_per_week", "int"),
    ("native_country", "category"),
    ("income_class", "category"),
])
target_column = "income_class"

# %%
def read_dataset(path):
    return pd.read_csv(
        path,
        names=data_types,
        index_col=None,

        comment='|',  # test dataset has comment in it
        skipinitialspace=True,  # Skip spaces after delimiter
        na_values={
            'capital_gain': 99999,
            'workclass': '?',
            'native_country': '?',
            'occupation': '?',
        },
        dtype=data_types,
    )

def clean_dataset(data):
    # Test dataset has dot at the end, we remove it in order
    # to unify names between training and test datasets.
    data['income_class'] = data.income_class.str.rstrip('.').astype('category')

    # Remove final weight column since there is no use
    # for it during the classification.
    data = data.drop('final_weight', axis=1)

    # Duplicates might create biases during the analysis and
    # during prediction stage they might give over-optimistic
    # (or pessimistic) results.
    data = data.drop_duplicates()

    # Binary target variable (>50K == 1 and <=50K == 0)
    data[target_column] = (data[target_column] == '>50K').astype(int)

    # Categorical dataset
    categorical_features = data.select_dtypes('category').columns
    data[categorical_features] = data.select_dtypes('category').apply(lambda x: x.cat.codes)
    return data

# %%
import pandas as pd
# get and clean train dataset
TRAIN_DATA_FILE = 'https://archive.ics.uci.edu/ml/machine-learning-databases/adult/adult.data'
train_data = clean_dataset(read_dataset(TRAIN_DATA_FILE))
train_data = train_data.dropna()
print("Train dataset shape:", train_data.shape)

# get and clean test dataset
TEST_DATA_FILE = 'https://archive.ics.uci.edu/ml/machine-learning-databases/adult/adult.test'
test_data = clean_dataset(read_dataset(TEST_DATA_FILE))
test_data = test_data.dropna()
print("Test dataset shape:", test_data.shape)
# Out:
# Train dataset shape: (28938, 14)
# Test dataset shape: (15175, 14)

# %%
target_column = "income_class"
features = train_data.columns.difference([target_column])
sensitive_feature = ["sex"]
non_sensitive_features = list(set(features).difference(set(sensitive_feature)))

# %%
from sklearn.model_selection import train_test_split
X_train, X_val, y_train, y_val = train_test_split(train_data[features], train_data[[target_column]], test_size=0.1)
X_test, y_test = test_data[features], test_data[[target_column]]

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_train = pd.DataFrame(scaler.fit_transform(X_train),columns = features)
X_val = pd.DataFrame(scaler.transform(X_val),columns = features)
X_test = pd.DataFrame(scaler.transform(X_test),columns = features)
# Out:
# /home/blackangoo/miniconda3/envs/MachineLearning/lib/python3.11/site-packages/sklearn/utils/validation.py:767: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if not hasattr(array, "sparse") and array.dtypes.apply(is_sparse).any():
# /home/blackangoo/miniconda3/envs/MachineLearning/lib/python3.11/site-packages/sklearn/utils/validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# /home/blackangoo/miniconda3/envs/MachineLearning/lib/python3.11/site-packages/sklearn/utils/validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):
# /home/blackangoo/miniconda3/envs/MachineLearning/lib/python3.11/site-packages/sklearn/utils/validation.py:767: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if not hasattr(array, "sparse") and array.dtypes.apply(is_sparse).any():
# /home/blackangoo/miniconda3/envs/MachineLearning/lib/python3.11/site-packages/sklearn/utils/validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# /home/blackangoo/miniconda3/envs/MachineLearning/lib/python3.11/site-packages/sklearn/utils/validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):
# /home/blackangoo/miniconda3/envs/MachineLearning/lib/python3.11/site-packages/sklearn/utils/validation.py:767: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if not hasattr(array, "sparse") and array.dtypes.apply(is_sparse).any():
# /home/blackangoo/miniconda3/envs/MachineLearning/lib/python3.11/site-packages/sklearn/utils/validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# /home/blackangoo/miniconda3/envs/MachineLearning/lib/python3.11/site-packages/sklearn/utils/validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):
# /home/blackangoo/miniconda3/envs/MachineLearning/lib/python3.11/site-packages/sklearn/utils/validation.py:767: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if not hasattr(array, "sparse") and array.dtypes.apply(is_sparse).any():
# /home/blackangoo/miniconda3/envs/MachineLearning/lib/python3.11/site-packages/sklearn/utils/validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# /home/blackangoo/miniconda3/envs/MachineLearning/lib/python3.11/site-packages/sklearn/utils/validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):

# %%
X_train.shape, X_val.shape, X_test.shape
# Out:
# ((26044, 13), (2894, 13), (15175, 13))

# %% [markdown]
# # Neural Networks
#
# Neural Networks are powerful function approximator that archives state-of-the-art performance on a lot of application the last decade on machine learning.
#
# The performance of the Deep Neural Network's is due to their high number of parameters and the efficient learning methods used to train those networks.
# For example the gtp-3 languages model was about by 175 billion parameters.
#
# Neural Networks, adjust their parameters (training), using the gradient descent method to **minimise a loss function** $L$.

# %% [markdown]
# <figure>
#   <img style="float: left;" src="./figures/neural_net_new.png" width="800"/>
# </figure>|

# %% [markdown]
# ### Operation of each node

# %% [markdown]
# <figure>
#   <img style="float: left;" src="./figures/neuron_2.png" width="600"/>
# </figure>

# %% [markdown]
# # Activation Functions
#
# Activation functions play an integral role in neural networks by introducing non-linearity.
# This non-linearity allows neural networks to develop complex representations and functions based on the inputs that would not be possible with a simple linear layers.
#
# Bellow we illustrate some of the most famous activation functions

# %% [markdown]
# <figure>
#   <img style="float: left;" src="./figures/acitvation_fun.png" width="600"/>
# </figure>

# %% [markdown]
# # Classification problem
#
# In classification problem the output of the neural network can be probability of each class p(y|x).
#
# So for binary classification we can do that using a single output to indicate the p(y=1|x).
# This has to be bounded between [0,1] in order to be a probability.
# To do so we can use the sigmoid function that we can illustrate bellow.
#
# <figure>
#   <img style="float: left;" src="./figures/sigmoid.png" width="400"/>
# </figure>

# %% [markdown]
# Then we can use the binary cross entropy loss as the **loss function**
#
# <figure>
#   <img style="float: left;" src="./figures/binary_ce.png" width="400"/>
# </figure>

# %% [markdown]
# Where
# $$\hat{Y} = f(x) = p(y=1|x)$$

# %% [markdown]
# As a note, for regression problem we don't use activation function in the final layer, while loss function is usually the mean square error.

# %% [markdown]
# # Define Neural Network with pytorch
#
# We will implement a simple neural network for classification problem with pytorch.
# The following network has 2 hidden layers following by an output layer.

# %%
class NeuralNetwork(torch.nn.Module):
    """
    Simple two layer neural network for regression
    """
    def __init__(self, num_input_features):
        super().__init__()
        
        # layer 1
        layer_1_units = 200
        self.layer_1 = torch.nn.Linear(in_features=num_input_features,
                                       out_features=layer_1_units)
        self.activation_1 = torch.nn.ReLU()
        
        # layer  2
        layer_2_units = 100
        self.layer_2 = torch.nn.Linear(in_features=layer_1_units,
                                       out_features=layer_2_units)
        self.activation_2 = torch.nn.ReLU()
        
        # layer output layer
        self.out_layer = torch.nn.Linear(in_features=layer_2_units,
                                         out_features=1)
        self.out_activation= torch.nn.Sigmoid()

    def forward(self, x):
        x_1 = self.activation_1( self.layer_1( x ) )
        x_2 = self.activation_2( self.layer_2( x_1 ) )
        output = self.out_activation(self.out_layer(x_2))
        return output

# %%
from torchsummary import summary
model = NeuralNetwork(num_input_features=12)
summary(model, input_size= [[12]])
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Linear-1                  [-1, 200]           2,600
#               ReLU-2                  [-1, 200]               0
#             Linear-3                  [-1, 100]          20,100
#               ReLU-4                  [-1, 100]               0
#             Linear-5                    [-1, 1]             101
#            Sigmoid-6                    [-1, 1]               0
# ================================================================
# Total params: 22,801
# Trainable params: 22,801
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.00
# Params size (MB): 0.09
# Estimated Total Size (MB): 0.09
# ----------------------------------------------------------------

# %% [markdown]
# ### make predictions

# %%
x = torch.rand((100,12))
y = torch.randint(0, 1, (100,1))
                  
predicted_proba = model.forward(x)

# %%
predicted_proba.shape # p(y=1|x)
# Out:
# torch.Size([100, 1])

# %%
predicted_proba
# Out:
# tensor([[0.4566],
#         [0.4625],
#         [0.4531],
#         [0.4646],
#         [0.4489],
#         [0.4510],
#         [0.4487],
#         [0.4633],
#         [0.4525],
#         [0.4694],
#         [0.4588],
#         [0.4601],
#         [0.4591],
#         [0.4609],
#         [0.4560],
#         [0.4598],
#         [0.4479],
#         [0.4664],
#         [0.4564],
#         [0.4708],
#         [0.4621],
#         [0.4619],
#         [0.4546],
#         [0.4560],
#         [0.4601],
#         [0.4463],
#         [0.4529],
#         [0.4592],
#         [0.4551],
#         [0.4579],
#         [0.4520],
#         [0.4574],
#         [0.4591],
#         [0.4516],
#         [0.4525],
#         [0.4425],
#         [0.4615],
#         [0.4554],
#         [0.4560],
#         [0.4536],
#         [0.4520],
#         [0.4654],
#         [0.4594],
#         [0.4605],
#         [0.4581],
#         [0.4587],
#         [0.4565],
#         [0.4500],
#         [0.4596],
#         [0.4501],
#         [0.4626],
#         [0.4546],
#         [0.4468],
#         [0.4546],
#         [0.4613],
#         [0.4589],
#         [0.4607],
#         [0.4498],
#         [0.4633],
#         [0.4658],
#         [0.4579],
#         [0.4517],
#         [0.4509],
#         [0.4574],
#         [0.4534],
#         [0.4573],
#         [0.4521],
#         [0.4594],
#         [0.4593],
#         [0.4490],
#         [0.4695],
#         [0.4660],
#         [0.4508],
#         [0.4524],
#         [0.4571],
#         [0.4522],
#         [0.4687],
#         [0.4686],
#         [0.4601],
#         [0.4584],
#         [0.4591],
#         [0.4588],
#         [0.4609],
#         [0.4566],
#         [0.4647],
#         [0.4510],
#         [0.4536],
#         [0.4558],
#         [0.4508],
#         [0.4514],
#         [0.4686],
#         [0.4512],
#         [0.4661],
#         [0.4596],
#         [0.4560],
#         [0.4514],
#         [0.4613],
#         [0.4652],
#         [0.4514],
#         [0.4588]], grad_fn=<SigmoidBackward0>)

# %% [markdown]
# ### optimise network
# perfom a single iteration of sgd.

# %%
model = NeuralNetwork(num_input_features=12)

# to make the optimization pytorch has different optimizers. 
lr = 0.01
optimizer = torch.optim.SGD(model.parameters(), lr=lr)
loss_fn = torch.nn.BCELoss()

# %%
model.layer_2.weight
# Out:
# Parameter containing:
# tensor([[-0.0471, -0.0358,  0.0048,  ..., -0.0313,  0.0080, -0.0216],
#         [ 0.0603, -0.0510, -0.0205,  ..., -0.0705, -0.0643, -0.0343],
#         [-0.0195,  0.0432, -0.0287,  ...,  0.0600,  0.0613,  0.0530],
#         ...,
#         [ 0.0232,  0.0659,  0.0334,  ...,  0.0590,  0.0179,  0.0292],
#         [-0.0082, -0.0426,  0.0450,  ..., -0.0200, -0.0695, -0.0133],
#         [-0.0009, -0.0465, -0.0020,  ..., -0.0447,  0.0557, -0.0201]],
#        requires_grad=True)

# %%
x = torch.rand((100, 12))
y = torch.randint(0, 1, (100, 1), dtype = torch.float)
                  
predicted_proba = model.forward(x)
loss = loss_fn(predicted_proba, y)
                  
loss.backward()
optimizer.step() # the optimiser aply the gradients to change the weights.

optimizer.zero_grad() # reset the gradients

# %%
model.layer_2.weight
# Out:
# Parameter containing:
# tensor([[-0.0471, -0.0358,  0.0048,  ..., -0.0313,  0.0080, -0.0216],
#         [ 0.0603, -0.0510, -0.0205,  ..., -0.0704, -0.0643, -0.0343],
#         [-0.0195,  0.0433, -0.0286,  ...,  0.0601,  0.0613,  0.0530],
#         ...,
#         [ 0.0232,  0.0658,  0.0334,  ...,  0.0590,  0.0179,  0.0292],
#         [-0.0082, -0.0427,  0.0448,  ..., -0.0201, -0.0695, -0.0133],
#         [-0.0009, -0.0465, -0.0019,  ..., -0.0447,  0.0557, -0.0201]],
#        requires_grad=True)

# %% [markdown]
# # Batching data
#
# When we train neural network we usually train our model using batches of training example.
#
#
# <figure>
#   <img style="float: left;" src="./figures/batches.png" width="500"/>
# </figure>
#
#
#
# Batching method is performed for different reasons.
# First of all in we have a huge dataset we cannot fit all the data in our memery.
# Moreover, using batches requires less time to fit the model as in the same time you can perform more update in the weights of the model. One drawback of using batches is that we approximate the gradient directions, so having very small batch size can affect the coverage of your model.
#
# So batch size is an additional hyperparameter of our training algorithm.

# %% [markdown]
# <figure>
#   <img style="float: left;" src="./figures/train_loop.png" width="500"/>
# </figure>

# %% [markdown]
# lets use pytorch to batch our data.
#
# In summary PyTorch provides two main data classes: **DataLoader** and **Dataset** to handle your data.
#
# **Dataset**  stores the samples and their corresponding labels, and **DataLoader** wraps an iterable around the Dataset to enable easy access to the batches.
#
# you can read more at: https://pytorch.org/tutorials/beginner/basics/data_tutorial.html

# %%
# covert data into tensors
train_x_tensor = torch.tensor(X_train.values, dtype=torch.float)
train_y_tensor = torch.tensor(y_train.values, dtype=torch.float)

# use the dataset class wrapper for tensors
train_tensor_dataset = torch.utils.data.TensorDataset(train_x_tensor, train_y_tensor)# there are more coplex dataset
                                                                                     # i.e images or text data

# pass the dataset class into Dataloader to batch and shuffle your data
train_dataloader = torch.utils.data.DataLoader(train_tensor_dataset,
                                               batch_size=64,
                                               shuffle=True)

# %%
for batch in enumerate(train_dataloader):
    batch_x, batch_y = next(iter(train_dataloader)) # get next iteam
batch_x.shape
# Out:
# torch.Size([64, 13])

# %%
batch_x
# Out:
# tensor([[-0.5975, -0.2438, -0.2310, -2.3424, -1.1718,  1.9201, -0.3871, -1.2815,
#          -0.3879,  0.4169, -0.9108,  0.7178,  0.0877],
#         [-0.0860,  0.8139, -0.2310,  0.2062, -0.4119, -0.8332, -0.3871, -1.2815,
#          -0.1518,  0.4169, -0.9108,  0.7178,  0.0877],
#         [ 1.5947, -0.2438, -0.2310, -2.0876, -0.7919, -0.0466, -0.3871,  0.3084,
#          -0.8601,  0.4169, -0.9108,  0.7178,  2.0965],
#         [-0.0129, -0.2438, -0.2310, -0.8132,  0.7280,  1.5267,  0.9114,  0.3084,
#           1.7370, -1.8413, -0.2952,  0.7178,  0.0877],
#         [ 0.4255, -0.2438, -0.2310,  0.4611,  1.4880,  1.9201, -0.3871,  0.3084,
#          -0.6240,  0.4169, -0.9108,  0.7178,  0.0877],
#         [-0.6706, -0.2438,  3.8361, -0.3035,  1.1080,  0.3467, -0.3871,  0.3084,
#           0.7926,  0.4169, -0.9108,  0.7178,  0.0877],
#         [ 1.5947, -0.2438, -0.2310, -1.3230, -2.3118, -0.0466, -0.3871,  0.3084,
#          -0.3879, -1.8413, -0.9108,  0.7178,  0.0877],
#         [-0.8167, -0.2438, -0.2310,  0.2062, -0.4119, -0.0466,  1.5606, -1.2815,
#          -1.5685,  0.4169,  1.5516, -1.3931, -2.5907],
#         [-0.6706,  5.3734, -0.2310,  0.4611,  1.4880,  1.5267, -0.3871, -4.4614,
#          -0.6240,  0.4169, -0.9108,  0.7178,  0.7573],
#         [-0.6706, -0.2438, -0.2310,  1.2257, -0.0319, -0.0466,  0.9114,  0.3084,
#           0.3204,  0.4169, -0.2952, -1.3931,  0.0877],
#         [-0.3783, -0.2438, -0.2310,  0.4611,  1.4880,  0.7401, -1.6855,  0.3084,
#           0.7926,  0.4169, -0.2952, -1.3931, -1.2515],
#         [ 2.7639, -0.2438, -0.2310,  0.2062, -0.4119, -2.4066,  2.2099,  0.3084,
#          -1.3323,  0.4169, -0.2952, -1.3931,  0.0877],
#         [-0.3783, -0.2438, -0.2310,  1.2257, -0.0319, -0.0466,  0.9114,  0.3084,
#          -1.3323,  0.4169,  0.9360,  0.7178,  0.0877],
#         [-0.7437, -0.2438, -0.2310,  0.2062, -0.4119,  3.1000, -1.0363,  0.3084,
#           1.7370,  0.4169, -0.9108,  0.7178,  0.0877],
#         [-1.3283, -0.2438, -0.2310, -1.0681, -1.9318, -0.0466,  0.2622,  0.3084,
#          -0.1518,  0.4169,  0.9360,  0.7178,  0.0877],
#         [ 0.0602, -0.2438, -0.2310,  1.2257, -0.0319, -0.8332, -1.6855, -2.8714,
#           1.5009,  0.4169, -0.2952,  0.7178,  0.0877],
#         [ 1.3024, -0.2438, -0.2310,  0.2062, -0.4119, -0.0466, -0.3871,  0.3084,
#          -0.6240,  0.4169,  2.1672, -1.3931,  0.0877],
#         [ 0.4986, -0.2438, -0.2310,  0.2062, -0.4119,  0.7401, -0.3871,  0.3084,
#          -0.8601,  0.4169, -0.9108,  0.7178,  0.0877],
#         [-0.5244, -0.2438, -0.2310,  0.2062, -0.4119, -0.0466, -1.6855,  0.3084,
#          -0.8601,  0.4169,  1.5516,  0.7178,  1.4269],
#         [-0.8898, -0.2438, -0.2310, -2.3424, -1.1718, -0.0466, -0.3871,  0.3084,
#          -0.8601,  0.4169, -0.9108,  0.7178,  1.4269],
#         [ 0.5717, -0.2438, -0.2310, -1.3230, -2.3118, -0.0466, -0.3871, -0.4254,
#           0.0843, -0.7122,  2.1672, -1.3931,  0.0877],
#         [ 0.6447, -0.2438, -0.2310,  0.4611,  1.4880, -0.0466, -0.3871,  0.3084,
#           0.7926,  0.4169, -0.9108,  0.7178, -1.2515],
#         [-0.8167, -0.2438, -0.2310, -2.3424, -1.1718, -0.0466, -0.3871,  0.3084,
#          -0.8601,  0.4169, -0.9108,  0.7178,  0.0877],
#         [ 0.1332,  5.1192, -0.2310,  0.2062, -0.4119, -0.0466,  0.9114,  0.3084,
#           1.7370,  0.4169, -0.2952, -1.3931,  2.0965],
#         [-0.3052, -0.2438, -0.2310, -2.3424, -1.1718,  0.3467,  0.9114,  0.3084,
#           1.2648,  0.4169, -0.2952,  0.7178,  0.0877],
#         [ 0.0602, -0.2438, -0.2310,  0.2062, -0.4119,  0.7401,  0.9114,  0.3084,
#          -0.8601,  0.4169, -0.2952,  0.7178,  0.0877],
#         [ 1.3755, -0.2438, -0.2310,  0.2062, -0.4119,  1.5267, -0.3871,  0.3084,
#           1.7370,  0.4169, -0.9108,  0.7178,  0.0877],
#         [ 1.0832, -0.2438, -0.2310,  0.2062, -0.4119, -0.4399, -0.3871,  0.3084,
#           0.3204,  0.4169,  2.1672, -1.3931,  0.0877],
#         [ 1.5947, -0.2438, -0.2310,  0.2062, -0.4119, -0.0466, -1.6855, -4.2168,
#          -1.3323,  0.4169, -0.2952, -1.3931,  0.0877],
#         [-0.3052,  2.4848, -0.2310, -0.3035,  1.1080, -0.0466, -0.3871, -0.7923,
#           1.2648, -2.9704, -0.9108,  0.7178, -1.2515],
#         [ 0.8640, -0.2438, -0.2310,  0.2062, -0.4119, -0.0466, -0.3871,  0.3084,
#          -1.5685,  0.4169, -0.9108,  0.7178, -2.5907],
#         [ 1.4486, -0.2438, -0.2310, -2.3424, -1.1718, -0.0466, -1.6855,  0.3084,
#          -1.3323,  0.4169,  1.5516, -1.3931,  0.0877],
#         [-0.0129, -0.2438, -0.2310,  0.2062, -0.4119, -0.0466,  0.9114,  0.3084,
#           0.0843,  0.4169,  1.5516,  0.7178,  0.0877],
#         [ 0.9370, -0.2438, -0.2310,  0.2062, -0.4119, -0.0466, -0.3871,  0.3084,
#          -1.5685,  0.4169, -0.9108,  0.7178, -2.5907],
#         [-0.8898, -0.2438, -0.2310,  0.2062, -0.4119,  3.1000,  0.9114,  0.3084,
#          -0.3879,  0.4169,  0.9360,  0.7178,  1.4269],
#         [-0.3052, -0.2438,  3.8361,  0.2062, -0.4119, -0.0466, -0.3871,  0.3084,
#          -0.8601,  0.4169, -0.9108,  0.7178,  0.0877],
#         [ 0.1332, -0.2438, -0.2310,  0.2062, -0.4119,  0.6614, -0.3871,  0.3084,
#           1.2648,  0.4169, -0.9108,  0.7178,  0.0877],
#         [-0.0129, -0.2438,  4.2147,  1.2257, -0.0319,  0.7401, -0.3871,  0.3084,
#          -0.6240,  0.4169, -0.9108,  0.7178, -1.9211],
#         [ 0.2794, -0.2438, -0.2310,  1.2257, -0.0319, -0.0466, -1.6855,  0.3084,
#          -1.5685,  0.4169, -0.2952, -1.3931, -2.5907],
#         [ 0.4986, -0.2438, -0.2310,  0.2062, -0.4119, -2.0132, -1.6855,  0.3084,
#          -1.5685,  0.4169, -0.2952, -1.3931, -2.5907],
#         [-0.0129, -0.2438,  4.1539, -0.3035,  1.1080,  0.7401,  0.9114,  0.3084,
#           1.2648,  0.4169, -0.2952,  0.7178,  0.0877],
#         [-0.0860, -0.2438, -0.2310,  0.2062, -0.4119,  1.1334, -0.3871,  0.3084,
#           1.2648,  0.4169, -0.9108,  0.7178,  0.0877],
#         [ 0.1332, -0.2438, -0.2310,  1.2257, -0.0319, -0.5973,  0.9114,  0.3084,
#           1.2648, -1.8413, -0.2952,  0.7178,  0.0877],
#         [-1.3283, -0.0217, -0.2310,  0.2062, -0.4119, -0.0466,  0.9114,  0.3084,
#          -0.8601,  0.4169,  0.9360,  0.7178,  0.0877],
#         [ 0.3524, -0.2438, -0.2310, -2.3424, -1.1718,  0.2681, -1.6855,  0.3084,
#           1.2648,  0.4169,  1.5516, -1.3931,  0.0877],
#         [ 0.0602,  1.4948, -0.2310, -0.3035,  1.1080,  0.5827,  0.9114,  0.3084,
#          -0.6240,  0.4169, -0.2952, -1.3931,  0.0877],
#         [-0.5244, -0.2438,  5.4138, -0.3035,  1.1080,  0.5827, -0.3871,  0.3084,
#           0.7926,  0.4169, -0.9108,  0.7178,  0.0877],
#         [-0.0129, -0.2438, -0.2310,  0.2062, -0.4119, -0.0466, -0.3871,  0.3084,
#          -0.8601,  0.4169, -0.9108,  0.7178,  0.0877],
#         [-1.0360,  2.9768, -0.2310,  1.2257, -0.0319, -0.0466,  0.9114,  0.3084,
#           0.7926,  0.4169, -0.2952,  0.7178,  0.0877],
#         [-1.1090, -0.2438, -0.2310, -0.3035,  1.1080,  0.7401,  0.9114,  0.3084,
#          -0.3879,  0.4169,  1.5516,  0.7178,  1.4269],
#         [ 1.7409, -0.2438, -0.2310,  0.9708,  1.8679, -0.0466, -0.3871,  0.3084,
#          -1.5685,  0.4169, -0.9108,  0.7178, -2.5907],
#         [-1.6206, -0.2438, -0.2310, -2.3424, -1.1718, -2.0132,  0.9114,  0.3084,
#           0.7926, -1.8413,  0.9360,  0.7178, -1.2515],
#         [ 1.3755, -0.2438, -0.2310,  0.2062, -0.4119, -0.0466, -0.3871,  0.3084,
#          -0.1518,  0.4169, -0.9108,  0.7178,  1.4269],
#         [ 2.6908, -0.2438, -0.2310, -2.5973, -1.5518, -2.2492,  2.2099,  0.3084,
#           1.2648, -1.8413,  1.5516, -1.3931,  0.0877],
#         [-0.7437, -0.2438, -0.2310, -0.5584,  0.3481, -0.0466,  0.9114,  0.3084,
#          -0.6240, -1.8413, -0.2952, -1.3931,  0.0877],
#         [ 0.4255, -0.2438, -0.2310,  1.2257, -0.0319, -0.2039, -1.6855,  0.3084,
#          -1.3323, -1.8413,  1.5516, -1.3931, -1.2515],
#         [ 1.5947, -0.2438, -0.2310,  0.2062, -0.4119, -0.0466, -0.3871,  0.3084,
#           1.7370, -1.8413, -0.9108,  0.7178,  1.4269],
#         [ 0.7909, -0.2438,  3.4597, -1.3230, -2.3118,  1.9201, -0.3871, -4.2168,
#           1.7370,  0.4169, -0.9108,  0.7178,  0.0877],
#         [ 0.1332, -0.2438, -0.2310, -0.3035,  1.1080, -0.8332,  1.5606,  0.3084,
#           1.2648,  0.4169,  1.5516, -1.3931,  0.0877],
#         [-0.2321, -0.2438, -0.2310,  0.2062, -0.4119,  0.2681, -0.3871,  0.3084,
#           0.0843,  0.4169, -0.9108,  0.7178,  0.0877],
#         [-1.1090, -0.2438, -0.2310,  0.2062, -0.4119, -0.0466, -0.3871, -1.2815,
#          -1.5685,  0.4169,  2.1672, -1.3931, -2.5907],
#         [-0.0860, -0.2438, -0.2310, -1.3230, -2.3118, -0.0466, -1.6855,  0.3084,
#           1.2648,  0.4169,  1.5516, -1.3931,  0.0877],
#         [-0.0129, -0.2438, -0.2310,  0.2062, -0.4119,  1.5267, -0.3871,  0.3084,
#           1.7370,  0.4169, -0.9108,  0.7178,  1.4269],
#         [-0.5244, -0.2438, -0.2310,  0.2062, -0.4119, -0.0466,  0.9114,  0.3084,
#           0.0843,  0.4169, -0.2952,  0.7178,  0.0877]])

# %%
# convert val data to tensor for later
val_x_tensor = torch.tensor(X_val.values, dtype=torch.float)
val_y_tensor = torch.tensor(y_val.values, dtype=torch.float)

# %% [markdown]
# # Define training loop

# %% [markdown]
# <figure>
#   <img style="float: left;" src="./figures/train_loop.png" width="400"/>
# </figure>

# %%
def training_step(model, input_data, optimizer, loss_fn):
    # reset gradients of the optimizer
    optimizer.zero_grad()
    
    # unfold data
    x_batch, y_batch = input_data
    
    # get predictions
    y_pred_propa = model(x_batch)
    
    # calculate loss
    loss = loss_fn(y_pred_propa, y_batch)

    # compute gradients 
    loss.backward()
    
    # optimise network
    optimizer.step()
    
    # compute metrics for monitoring
    with torch.no_grad(): 
        y_pred = (y_pred_propa>0.5) * 1
        train_acc = torch.sum(y_pred == y_batch) / y_batch.shape[0]

    return loss.data.numpy(), train_acc.data.numpy()

# %%
def evaluation_step(model, input_data, loss_fn):
    # when we use torch.no_grad pytorch didnt store information
    # that is required to calculate gradients so is fasterr 
    with torch.no_grad(): 
        x_batch, y_batch = input_data
        y_pred_proba = model(x_batch)
        loss = loss_fn(y_pred_proba, y_batch)

        # compute metrics
        y_pred = (y_pred_proba>0.5) * 1
        acc = torch.sum(y_pred == y_batch) / y_batch.shape[0]
    return loss.data.numpy(), acc.data.numpy()

# %%
model = NeuralNetwork(num_input_features=13)

lr = 0.02
optimizer = torch.optim.SGD(model.parameters(), lr=lr)
loss_fn = torch.nn.BCELoss() # binary cross entropy

# %%
# parameters of the training loop
epochs = 400

# %%
# -------------------- Train  Loop----------------------------
train_history = []
val_history = []
for epoch in range(epochs): # iterate over epoch    

    # -------------------- 1. Training on each epoch ----------------------------
    accumulated_loss,accumulated_accuracy = 0, 0 # monitor loss and metrics during training
    for step, batch_data in enumerate(train_dataloader): # iterate over batch
        loss, accuracy = training_step(model,batch_data,optimizer,loss_fn) # train model using a single batch
        accumulated_loss = (step * accumulated_loss + loss)/(step+1)
        accumulated_accuracy =  (step * accumulated_accuracy + accuracy)/(step+1)
        
    # store the loss and the metrics at the end of each epoch
    train_history += [{"loss":accumulated_loss, "accuracy":accumulated_accuracy, "epoch": epoch}]
    
    # -------------------- 2. Monitor Error on Validation set ----------------------------
    val_loss, val_accuracy = evaluation_step(model, (val_x_tensor, val_y_tensor), loss_fn)
    val_history += [{"loss":val_loss, "accuracy":val_accuracy, "epoch": epoch}]
    if epoch % 10 == 0:
        print(f"Epoch {epoch}/{epochs}:  loss:{accumulated_loss:.3f}, accuracy-:{accumulated_accuracy:.3f}, val_loss:{val_loss:.3f}, val_accuracy->{val_accuracy:.3f}")
# Out:
# Epoch 0/400:  loss:0.466, accuracy-:0.787, val_loss:0.415, val_accuracy->0.808
# Epoch 10/400:  loss:0.332, accuracy-:0.844, val_loss:0.349, val_accuracy->0.827
# Epoch 20/400:  loss:0.325, accuracy-:0.848, val_loss:0.343, val_accuracy->0.830
# Epoch 30/400:  loss:0.320, accuracy-:0.850, val_loss:0.338, val_accuracy->0.832
# Epoch 40/400:  loss:0.316, accuracy-:0.851, val_loss:0.337, val_accuracy->0.832
# Epoch 50/400:  loss:0.312, accuracy-:0.853, val_loss:0.335, val_accuracy->0.838
# Epoch 60/400:  loss:0.309, accuracy-:0.855, val_loss:0.335, val_accuracy->0.839
# Epoch 70/400:  loss:0.306, accuracy-:0.855, val_loss:0.334, val_accuracy->0.835
# Epoch 80/400:  loss:0.302, accuracy-:0.857, val_loss:0.334, val_accuracy->0.836
# Epoch 90/400:  loss:0.300, accuracy-:0.858, val_loss:0.338, val_accuracy->0.831
# Epoch 100/400:  loss:0.297, accuracy-:0.858, val_loss:0.333, val_accuracy->0.839
# Epoch 110/400:  loss:0.294, accuracy-:0.860, val_loss:0.336, val_accuracy->0.836
# Epoch 120/400:  loss:0.292, accuracy-:0.861, val_loss:0.335, val_accuracy->0.838
# Epoch 130/400:  loss:0.289, accuracy-:0.863, val_loss:0.346, val_accuracy->0.832
# Epoch 140/400:  loss:0.287, accuracy-:0.864, val_loss:0.350, val_accuracy->0.832
# Epoch 150/400:  loss:0.285, accuracy-:0.864, val_loss:0.343, val_accuracy->0.836
# Epoch 160/400:  loss:0.282, accuracy-:0.865, val_loss:0.350, val_accuracy->0.828
# Epoch 170/400:  loss:0.280, accuracy-:0.866, val_loss:0.349, val_accuracy->0.832
# Epoch 180/400:  loss:0.278, accuracy-:0.865, val_loss:0.349, val_accuracy->0.831
# Epoch 190/400:  loss:0.276, accuracy-:0.866, val_loss:0.354, val_accuracy->0.836
# Epoch 200/400:  loss:0.274, accuracy-:0.869, val_loss:0.363, val_accuracy->0.829
# Epoch 210/400:  loss:0.273, accuracy-:0.868, val_loss:0.353, val_accuracy->0.830
# Epoch 220/400:  loss:0.271, accuracy-:0.869, val_loss:0.364, val_accuracy->0.822
# Epoch 230/400:  loss:0.270, accuracy-:0.868, val_loss:0.360, val_accuracy->0.829
# Epoch 240/400:  loss:0.268, accuracy-:0.872, val_loss:0.358, val_accuracy->0.831
# Epoch 250/400:  loss:0.265, accuracy-:0.874, val_loss:0.367, val_accuracy->0.830
# Epoch 260/400:  loss:0.264, accuracy-:0.873, val_loss:0.364, val_accuracy->0.828
# Epoch 270/400:  loss:0.263, accuracy-:0.874, val_loss:0.373, val_accuracy->0.829
# Epoch 280/400:  loss:0.261, accuracy-:0.874, val_loss:0.373, val_accuracy->0.826
# Epoch 290/400:  loss:0.260, accuracy-:0.876, val_loss:0.393, val_accuracy->0.830
# Epoch 300/400:  loss:0.258, accuracy-:0.877, val_loss:0.373, val_accuracy->0.822
# Epoch 310/400:  loss:0.257, accuracy-:0.877, val_loss:0.386, val_accuracy->0.823
# Epoch 320/400:  loss:0.255, accuracy-:0.879, val_loss:0.379, val_accuracy->0.824
# Epoch 330/400:  loss:0.253, accuracy-:0.878, val_loss:0.396, val_accuracy->0.819
# Epoch 340/400:  loss:0.252, accuracy-:0.879, val_loss:0.391, val_accuracy->0.819
# Epoch 350/400:  loss:0.251, accuracy-:0.879, val_loss:0.395, val_accuracy->0.823
# Epoch 360/400:  loss:0.249, accuracy-:0.880, val_loss:0.411, val_accuracy->0.821
# Epoch 370/400:  loss:0.248, accuracy-:0.880, val_loss:0.398, val_accuracy->0.813
# Epoch 380/400:  loss:0.246, accuracy-:0.882, val_loss:0.398, val_accuracy->0.826
# Epoch 390/400:  loss:0.246, accuracy-:0.884, val_loss:0.397, val_accuracy->0.820

# %%
val_history_df = pd.DataFrame(val_history)
train_history_df = pd.DataFrame(train_history)

# %% [markdown]
# # Learning Curves and Overfitting
#
# **Overfitting** refers to the phenomenon when our model performs well on the training set but exhibits poor performance on the testing set.
#
# Since neural networks have a large number of parameters, they are prone to overfitting the training data, resulting in bad performance during testing.
# This occurs when the model exploits pattern between the data (X) and the labels (Y) that is not in the testing data.
#
# One way to monitor the performance of our algorithm is by using learning curves.
#
# Learning curves track the performance of the model during training by measuring various metrics at regular optimization steps.
# Learning curves provide valuable insights into the model's behavior, allowing us to detect overfitting.
#
#
# To identify overfitting, we typically compare the learning curves of the training and validation sets.

# %% [markdown]
# <figure>
#   <img style="float: left;" src="./figures/epoch-error-curve-fitting.png" width="400"/>
# </figure>

# %% [markdown]
# For example, in the plot above, we can observe the learning curves of the training and validation sets during training. At the beginning of training, the model minimizes the loss on both the training and validation sets. However, after several epochs, you can see that the validation error starts to increase while the training loss continues to decrease. This indicates that the model is learning patterns specific to the training set that do not generalize well to the validation set, leading to loss increases.

# %%
plt.figure()
plt.plot(train_history_df["epoch"],train_history_df["loss"], label = "Training set")
plt.plot(val_history_df["epoch"],val_history_df["loss"], label = "Validation set")
plt.title("Learning Curve")
plt.ylabel("Cross Entropy Loss")
plt.xlabel("Epoch")
plt.legend()

# %%
plt.figure()
plt.plot(train_history_df["epoch"],train_history_df["accuracy"], label = "Training set")
plt.plot(val_history_df["epoch"],val_history_df["accuracy"], label = "Validation set")
plt.title("Learning Curve")
plt.ylabel("Accuracy")
plt.xlabel("Epoch")
plt.legend()

# %% [markdown]
# # Assignment 6
#
# In the 6th assignment we will see the effect of different techniques to reduce overfitting when training a neural network.

# %% [markdown]
# # A. Early stopping
# Early stopping is an optimization technique used to reduce overfitting without compromising on model accuracy. The main idea behind early stopping is to stop training before a model starts to over-fit.
#
#
# To use early stopping, you watch for the validation loss. If it stops improving for several consecutive epochs , indicated by the "patient" parameter, you stop training.
#
# **Steps:**
#    1) Implement Early Stopping.
#    2) Train your model using early stopping.
#    3) Check different patient parameters. For example, you can set patient = {5 , 100}. Can the patient parameter affect the coverage of your network?

# %% [markdown]
# # Solution

# %%
# -------------------- Train  Loop----------------------------

consecutive_non_improving_epochs = 0
patient = 5

train_history = []
val_history = []
for epoch in range(epochs): # iterate over epoch    

    print(consecutive_non_improving_epochs)

    # -------------------- 1. Training on each epoch ----------------------------
    accumulated_loss,accumulated_accuracy = 0, 0 # monitor loss and metrics during training
    for step, batch_data in enumerate(train_dataloader): # iterate over batch
        loss, accuracy = training_step(model,batch_data,optimizer,loss_fn) # train model using a single batch
        accumulated_loss = (step * accumulated_loss + loss)/(step+1)
        accumulated_accuracy =  (step * accumulated_accuracy + accuracy)/(step+1)
        
    # store the loss and the metrics at the end of each epoch
    train_history += [{"loss":accumulated_loss, "accuracy":accumulated_accuracy, "epoch": epoch}]
    
    # -------------------- 2. Monitor Error on Validation set ----------------------------
    val_loss, val_accuracy = evaluation_step(model, (val_x_tensor, val_y_tensor), loss_fn)
    val_history += [{"loss":val_loss, "accuracy":val_accuracy, "epoch": epoch}]
    if epoch % 10 == 0:
        print(f"Epoch {epoch}/{epochs}:  loss:{accumulated_loss:.3f}, accuracy:{accumulated_accuracy:.3f}, val_loss:{val_loss:.3f}, val_accuracy->{val_accuracy:.3f}")

    if val_history[epoch-1]["loss"] < val_loss and epoch > 0:
        consecutive_non_improving_epochs += 1

    else:
        consecutive_non_improving_epochs = 0

    if consecutive_non_improving_epochs >= patient:
        print(f"Early stopping after {epoch} epochs without improvement.")
        break
# Out:
# Epoch 0/400:  loss:0.243, accuracy-:0.883, val_loss:0.423, val_accuracy->0.817
# Epoch 10/400:  loss:0.243, accuracy-:0.883, val_loss:0.396, val_accuracy->0.821
# Epoch 20/400:  loss:0.241, accuracy-:0.885, val_loss:0.404, val_accuracy->0.822
# Epoch 30/400:  loss:0.239, accuracy-:0.884, val_loss:0.419, val_accuracy->0.813
# Epoch 40/400:  loss:0.238, accuracy-:0.886, val_loss:0.428, val_accuracy->0.823
# Epoch 50/400:  loss:0.237, accuracy-:0.887, val_loss:0.408, val_accuracy->0.821
# Epoch 60/400:  loss:0.233, accuracy-:0.888, val_loss:0.440, val_accuracy->0.824
# Epoch 70/400:  loss:0.234, accuracy-:0.888, val_loss:0.473, val_accuracy->0.820
# Epoch 80/400:  loss:0.232, accuracy-:0.890, val_loss:0.421, val_accuracy->0.824
# Epoch 90/400:  loss:0.231, accuracy-:0.890, val_loss:0.429, val_accuracy->0.809
# Epoch 100/400:  loss:0.230, accuracy-:0.890, val_loss:0.439, val_accuracy->0.822
# Epoch 110/400:  loss:0.228, accuracy-:0.890, val_loss:0.438, val_accuracy->0.812
# Epoch 120/400:  loss:0.226, accuracy-:0.892, val_loss:0.445, val_accuracy->0.814
# Epoch 130/400:  loss:0.226, accuracy-:0.890, val_loss:0.429, val_accuracy->0.819
# Epoch 140/400:  loss:0.225, accuracy-:0.892, val_loss:0.427, val_accuracy->0.819
# Epoch 150/400:  loss:0.223, accuracy-:0.892, val_loss:0.462, val_accuracy->0.817
# Epoch 160/400:  loss:0.222, accuracy-:0.894, val_loss:0.476, val_accuracy->0.820
# Epoch 170/400:  loss:0.221, accuracy-:0.892, val_loss:0.460, val_accuracy->0.815
# Epoch 180/400:  loss:0.222, accuracy-:0.893, val_loss:0.445, val_accuracy->0.816
# Epoch 190/400:  loss:0.221, accuracy-:0.895, val_loss:0.490, val_accuracy->0.818
# Epoch 200/400:  loss:0.217, accuracy-:0.894, val_loss:0.467, val_accuracy->0.808
# Epoch 210/400:  loss:0.219, accuracy-:0.895, val_loss:0.466, val_accuracy->0.810
# Epoch 220/400:  loss:0.214, accuracy-:0.896, val_loss:0.472, val_accuracy->0.823
# Epoch 230/400:  loss:0.213, accuracy-:0.895, val_loss:0.460, val_accuracy->0.810
# Epoch 240/400:  loss:0.213, accuracy-:0.897, val_loss:0.473, val_accuracy->0.812
# Epoch 250/400:  loss:0.211, accuracy-:0.898, val_loss:0.476, val_accuracy->0.822
# Epoch 260/400:  loss:0.213, accuracy-:0.897, val_loss:0.467, val_accuracy->0.813
# Epoch 270/400:  loss:0.212, accuracy-:0.898, val_loss:0.467, val_accuracy->0.819
# Epoch 280/400:  loss:0.211, accuracy-:0.897, val_loss:0.524, val_accuracy->0.816
# Epoch 290/400:  loss:0.208, accuracy-:0.901, val_loss:0.478, val_accuracy->0.811
# Epoch 300/400:  loss:0.208, accuracy-:0.900, val_loss:0.512, val_accuracy->0.815
# Epoch 310/400:  loss:0.207, accuracy-:0.900, val_loss:0.521, val_accuracy->0.810
# Epoch 320/400:  loss:0.204, accuracy-:0.903, val_loss:0.547, val_accuracy->0.820
# Epoch 330/400:  loss:0.204, accuracy-:0.901, val_loss:0.539, val_accuracy->0.818
# Epoch 340/400:  loss:0.204, accuracy-:0.901, val_loss:0.504, val_accuracy->0.806
# Epoch 350/400:  loss:0.206, accuracy-:0.900, val_loss:0.520, val_accuracy->0.815
# Early stopping after 351 epochs without improvement.

# %% [markdown]
# # B. Reduce the Size of the Network
#
# The capacity (total number of parameters) of the model affects the training process. If the parameters are too numerous compared to the difficulty of the underlying problem, it's very easy to overfit.
#
# To address this issue, reduce the total number of parameters in the model by decreasing the number of units in each layer, and then comment on the results.
#
# **Steps:**
# 1. Reduce the size of the network by lowering the number of units. You can use 60 units for the first layer and 20 units for the second one.
# 2. Train your model without early stopping.
# 3. Compare the learning curve of this model with the learning curve of the larger model we trained without early stopping (used in section Learning Curves and Overfitting).

# %% [markdown]
# # Solution

# %%
class SmallerNeuralNetwork(torch.nn.Module):
    """
    Simple two layer neural network for regression
    """
    def __init__(self, num_input_features):
        super().__init__()
        
        # layer 1
        layer_1_units = 60
        self.layer_1 = torch.nn.Linear(in_features=num_input_features,
                                       out_features=layer_1_units)
        self.activation_1 = torch.nn.ReLU()
        
        # layer  2
        layer_2_units = 20
        self.layer_2 = torch.nn.Linear(in_features=layer_1_units,
                                       out_features=layer_2_units)
        self.activation_2 = torch.nn.ReLU()
        
        # layer output layer
        self.out_layer = torch.nn.Linear(in_features=layer_2_units,
                                         out_features=1)
        self.out_activation= torch.nn.Sigmoid()

    def forward(self, x):
        x_1 = self.activation_1( self.layer_1( x ) )
        x_2 = self.activation_2( self.layer_2( x_1 ) )
        output = self.out_activation(self.out_layer(x_2))
        return output

# %%
small_model = SmallerNeuralNetwork(num_input_features=13)

lr = 0.02
optimizer = torch.optim.SGD(small_model.parameters(), lr=lr)
loss_fn = torch.nn.BCELoss() # binary cross entropy

epochs = 400

# %%
# -------------------- Train  Loop----------------------------
small_train_history = []
small_val_history = []
for epoch in range(epochs): # iterate over epoch    

    # -------------------- 1. Training on each epoch ----------------------------
    accumulated_loss,accumulated_accuracy = 0, 0 # monitor loss and metrics during training
    for step, batch_data in enumerate(train_dataloader): # iterate over batch
        loss, accuracy = training_step(small_model,batch_data,optimizer,loss_fn) # train model using a single batch
        accumulated_loss = (step * accumulated_loss + loss)/(step+1)
        accumulated_accuracy =  (step * accumulated_accuracy + accuracy)/(step+1)
        
    # store the loss and the metrics at the end of each epoch
    small_train_history += [{"loss":accumulated_loss, "accuracy":accumulated_accuracy, "epoch": epoch}]
    
    # -------------------- 2. Monitor Error on Validation set ----------------------------
    val_loss, val_accuracy = evaluation_step(small_model, (val_x_tensor, val_y_tensor), loss_fn)
    small_val_history += [{"loss":val_loss, "accuracy":val_accuracy, "epoch": epoch}]
    if epoch % 10 == 0:
        print(f"Epoch {epoch}/{epochs}:  loss:{accumulated_loss:.3f}, accuracy:{accumulated_accuracy:.3f}, val_loss:{val_loss:.3f}, val_accuracy->{val_accuracy:.3f}")
# Out:
# Epoch 0/400:  loss:0.515, accuracy-:0.759, val_loss:0.462, val_accuracy->0.753
# Epoch 10/400:  loss:0.335, accuracy-:0.842, val_loss:0.346, val_accuracy->0.823
# Epoch 20/400:  loss:0.329, accuracy-:0.846, val_loss:0.341, val_accuracy->0.827
# Epoch 30/400:  loss:0.325, accuracy-:0.849, val_loss:0.337, val_accuracy->0.832
# Epoch 40/400:  loss:0.322, accuracy-:0.849, val_loss:0.337, val_accuracy->0.833
# Epoch 50/400:  loss:0.319, accuracy-:0.851, val_loss:0.334, val_accuracy->0.833
# Epoch 60/400:  loss:0.317, accuracy-:0.853, val_loss:0.334, val_accuracy->0.833
# Epoch 70/400:  loss:0.315, accuracy-:0.852, val_loss:0.335, val_accuracy->0.833
# Epoch 80/400:  loss:0.314, accuracy-:0.853, val_loss:0.334, val_accuracy->0.833
# Epoch 90/400:  loss:0.312, accuracy-:0.853, val_loss:0.332, val_accuracy->0.839
# Epoch 100/400:  loss:0.311, accuracy-:0.852, val_loss:0.330, val_accuracy->0.838
# Epoch 110/400:  loss:0.310, accuracy-:0.852, val_loss:0.330, val_accuracy->0.837
# Epoch 120/400:  loss:0.308, accuracy-:0.854, val_loss:0.333, val_accuracy->0.832
# Epoch 130/400:  loss:0.307, accuracy-:0.853, val_loss:0.333, val_accuracy->0.832
# Epoch 140/400:  loss:0.307, accuracy-:0.854, val_loss:0.333, val_accuracy->0.835
# Epoch 150/400:  loss:0.306, accuracy-:0.854, val_loss:0.332, val_accuracy->0.839
# Epoch 160/400:  loss:0.305, accuracy-:0.853, val_loss:0.336, val_accuracy->0.834
# Epoch 170/400:  loss:0.304, accuracy-:0.855, val_loss:0.333, val_accuracy->0.838
# Epoch 180/400:  loss:0.303, accuracy-:0.855, val_loss:0.338, val_accuracy->0.831
# Epoch 190/400:  loss:0.303, accuracy-:0.854, val_loss:0.336, val_accuracy->0.835
# Epoch 200/400:  loss:0.302, accuracy-:0.855, val_loss:0.334, val_accuracy->0.837
# Epoch 210/400:  loss:0.302, accuracy-:0.855, val_loss:0.336, val_accuracy->0.836
# Epoch 220/400:  loss:0.301, accuracy-:0.855, val_loss:0.336, val_accuracy->0.838
# Epoch 230/400:  loss:0.301, accuracy-:0.855, val_loss:0.337, val_accuracy->0.841
# Epoch 240/400:  loss:0.300, accuracy-:0.856, val_loss:0.343, val_accuracy->0.842
# Epoch 250/400:  loss:0.299, accuracy-:0.856, val_loss:0.339, val_accuracy->0.836
# Epoch 260/400:  loss:0.299, accuracy-:0.856, val_loss:0.337, val_accuracy->0.835
# Epoch 270/400:  loss:0.298, accuracy-:0.858, val_loss:0.337, val_accuracy->0.839
# Epoch 280/400:  loss:0.297, accuracy-:0.857, val_loss:0.337, val_accuracy->0.839
# Epoch 290/400:  loss:0.297, accuracy-:0.857, val_loss:0.344, val_accuracy->0.836
# Epoch 300/400:  loss:0.296, accuracy-:0.857, val_loss:0.339, val_accuracy->0.837
# Epoch 310/400:  loss:0.296, accuracy-:0.857, val_loss:0.352, val_accuracy->0.832
# Epoch 320/400:  loss:0.296, accuracy-:0.857, val_loss:0.344, val_accuracy->0.835
# Epoch 330/400:  loss:0.295, accuracy-:0.856, val_loss:0.342, val_accuracy->0.833
# Epoch 340/400:  loss:0.295, accuracy-:0.859, val_loss:0.343, val_accuracy->0.836
# Epoch 350/400:  loss:0.294, accuracy-:0.857, val_loss:0.347, val_accuracy->0.833
# Epoch 360/400:  loss:0.294, accuracy-:0.858, val_loss:0.346, val_accuracy->0.837
# Epoch 370/400:  loss:0.293, accuracy-:0.858, val_loss:0.347, val_accuracy->0.834
# Epoch 380/400:  loss:0.293, accuracy-:0.858, val_loss:0.352, val_accuracy->0.831
# Epoch 390/400:  loss:0.292, accuracy-:0.860, val_loss:0.347, val_accuracy->0.835

# %%
small_val_history_df = pd.DataFrame(small_val_history)
small_train_history_df = pd.DataFrame(small_train_history)

# %%
plt.figure()
plt.plot(small_train_history_df["epoch"],small_train_history_df["loss"], label = "Small training set")
plt.plot(small_val_history_df["epoch"],small_val_history_df["loss"], label = "Small validation set")
plt.plot(train_history_df["epoch"],train_history_df["loss"], label = "Large training set")
plt.plot(val_history_df["epoch"],val_history_df["loss"], label = "Large validation set")
plt.title("Learning Curve")
plt.ylabel("Cross Entropy Loss")
plt.xlabel("Epoch")
plt.legend()

# %%
plt.figure()
plt.plot(small_train_history_df["epoch"],small_train_history_df["accuracy"], label = "Small training set")
plt.plot(small_val_history_df["epoch"],small_val_history_df["accuracy"], label = "Small validation set")
plt.plot(train_history_df["epoch"],train_history_df["accuracy"], label = "Large training set")
plt.plot(val_history_df["epoch"],val_history_df["accuracy"], label = "Large validation set")
plt.title("Learning Curve")
plt.ylabel("Accuracy")
plt.xlabel("Epoch")
plt.legend()

# %% [markdown]
# # C. Weight Regularization
#
# Weight Regularization is another very famous technique to reduce overfitting.
# The concept of regularization is to add a constraint in the loss function to keep the weights of the model small.
#
# To get the intuition, weights regularization discourages the model from fitting the training data too closely and forces it to focus on the most important features. By constraining the model's weights, it can generalize better to new data because it's less likely to memorize the training examples and is more likely to capture underlying patterns and relationships in the data.
#
# A very famous and easy regularization is the L2-regularization where we modify the loss function as follows:
#
# $$ \text{Total Loss} = \mathbb{E}_{x,y \sim P_{data}} \left[ loss(f_w(x),y) \right] + \lambda \sum_{j=1}^{p} w_j^2 $$
#
# Where $\lambda$ is a scaling paramter, $loss$ in the loss function, $w$ the parameters of the model. Finally, $p$ indicates the set of different parameters
#
# In pytorch is very easy to apply L2-regularization. You can do that using the weight_decay ($\lambda$) parameter of the optimizer class.

# %% [markdown]
# ```python
# torch.optim.SGD(model.parameters(), lr=lr, weight_decay=λ)

# %% [markdown]
# **Steps :**
# 1) Use $\lambda = 0.01$ and train your model using L2 regularization, as explained before.
# Use the model architeture with the more paramter and dont aply early stoping to see the effect.
# 3) Compare with the initial training without early stoping (used in section Learning Curves and Overfitting) and comment on the results.

# %% [markdown]
# # Solution

# %%
class RegularizedNeuralNetwork(torch.nn.Module):
    """
    Simple two layer neural network for regression
    """
    def __init__(self, num_input_features):
        super().__init__()
        
        # layer 1
        layer_1_units = 200
        self.layer_1 = torch.nn.Linear(in_features=num_input_features,
                                       out_features=layer_1_units)
        self.activation_1 = torch.nn.ReLU()
        
        # layer  2
        layer_2_units = 100
        self.layer_2 = torch.nn.Linear(in_features=layer_1_units,
                                       out_features=layer_2_units)
        self.activation_2 = torch.nn.ReLU()
        
        # layer output layer
        self.out_layer = torch.nn.Linear(in_features=layer_2_units,
                                         out_features=1)
        self.out_activation= torch.nn.Sigmoid()

    def forward(self, x):
        x_1 = self.activation_1( self.layer_1( x ) )
        x_2 = self.activation_2( self.layer_2( x_1 ) )
        output = self.out_activation(self.out_layer(x_2))
        return output

# %%
regularized_model = RegularizedNeuralNetwork(num_input_features=13)

lr = 0.02
λ = 0.01
optimizer = torch.optim.SGD(regularized_model.parameters(), lr=lr, weight_decay=λ)
loss_fn = torch.nn.BCELoss() # binary cross entropy

epochs = 400

# %%
# -------------------- Train  Loop----------------------------
regularized_train_history = []
regularized_val_history = []
for epoch in range(epochs): # iterate over epoch    

    # -------------------- 1. Training on each epoch ----------------------------
    accumulated_loss,accumulated_accuracy = 0, 0 # monitor loss and metrics during training
    for step, batch_data in enumerate(train_dataloader): # iterate over batch
        loss, accuracy = training_step(regularized_model,batch_data,optimizer,loss_fn) # train model using a single batch
        accumulated_loss = (step * accumulated_loss + loss)/(step+1)
        accumulated_accuracy =  (step * accumulated_accuracy + accuracy)/(step+1)
        
    # store the loss and the metrics at the end of each epoch
    regularized_train_history += [{"loss":accumulated_loss, "accuracy":accumulated_accuracy, "epoch": epoch}]
    
    # -------------------- 2. Monitor Error on Validation set ----------------------------
    val_loss, val_accuracy = evaluation_step(regularized_model, (val_x_tensor, val_y_tensor), loss_fn)
    regularized_val_history += [{"loss":val_loss, "accuracy":val_accuracy, "epoch": epoch}]
    if epoch % 10 == 0:
        print(f"Epoch {epoch}/{epochs}:  loss:{accumulated_loss:.3f}, accuracy:{accumulated_accuracy:.3f}, val_loss:{val_loss:.3f}, val_accuracy->{val_accuracy:.3f}")
# Out:
# Epoch 0/400:  loss:0.465, accuracy-:0.781, val_loss:0.419, val_accuracy->0.806
# Epoch 10/400:  loss:0.342, accuracy-:0.839, val_loss:0.355, val_accuracy->0.823
# Epoch 20/400:  loss:0.337, accuracy-:0.843, val_loss:0.350, val_accuracy->0.821
# Epoch 30/400:  loss:0.337, accuracy-:0.843, val_loss:0.350, val_accuracy->0.821
# Epoch 40/400:  loss:0.337, accuracy-:0.842, val_loss:0.350, val_accuracy->0.821
# Epoch 50/400:  loss:0.337, accuracy-:0.842, val_loss:0.349, val_accuracy->0.823
# Epoch 60/400:  loss:0.336, accuracy-:0.843, val_loss:0.349, val_accuracy->0.821
# Epoch 70/400:  loss:0.337, accuracy-:0.843, val_loss:0.348, val_accuracy->0.823
# Epoch 80/400:  loss:0.336, accuracy-:0.843, val_loss:0.349, val_accuracy->0.820
# Epoch 90/400:  loss:0.336, accuracy-:0.842, val_loss:0.348, val_accuracy->0.822
# Epoch 100/400:  loss:0.336, accuracy-:0.843, val_loss:0.349, val_accuracy->0.823
# Epoch 110/400:  loss:0.336, accuracy-:0.843, val_loss:0.349, val_accuracy->0.823
# Epoch 120/400:  loss:0.336, accuracy-:0.843, val_loss:0.350, val_accuracy->0.824
# Epoch 130/400:  loss:0.336, accuracy-:0.843, val_loss:0.349, val_accuracy->0.822
# Epoch 140/400:  loss:0.336, accuracy-:0.843, val_loss:0.348, val_accuracy->0.821
# Epoch 150/400:  loss:0.336, accuracy-:0.843, val_loss:0.349, val_accuracy->0.822
# Epoch 160/400:  loss:0.336, accuracy-:0.843, val_loss:0.348, val_accuracy->0.824
# Epoch 170/400:  loss:0.336, accuracy-:0.844, val_loss:0.351, val_accuracy->0.824
# Epoch 180/400:  loss:0.336, accuracy-:0.843, val_loss:0.350, val_accuracy->0.826
# Epoch 190/400:  loss:0.336, accuracy-:0.843, val_loss:0.348, val_accuracy->0.821
# Epoch 200/400:  loss:0.336, accuracy-:0.843, val_loss:0.349, val_accuracy->0.823
# Epoch 210/400:  loss:0.336, accuracy-:0.843, val_loss:0.348, val_accuracy->0.823
# Epoch 220/400:  loss:0.336, accuracy-:0.843, val_loss:0.349, val_accuracy->0.821
# Epoch 230/400:  loss:0.336, accuracy-:0.842, val_loss:0.348, val_accuracy->0.823
# Epoch 240/400:  loss:0.336, accuracy-:0.843, val_loss:0.348, val_accuracy->0.822
# Epoch 250/400:  loss:0.336, accuracy-:0.843, val_loss:0.349, val_accuracy->0.822
# Epoch 260/400:  loss:0.336, accuracy-:0.843, val_loss:0.349, val_accuracy->0.822
# Epoch 270/400:  loss:0.336, accuracy-:0.842, val_loss:0.348, val_accuracy->0.821
# Epoch 280/400:  loss:0.336, accuracy-:0.842, val_loss:0.349, val_accuracy->0.820
# Epoch 290/400:  loss:0.336, accuracy-:0.843, val_loss:0.348, val_accuracy->0.822
# Epoch 300/400:  loss:0.336, accuracy-:0.842, val_loss:0.348, val_accuracy->0.826
# Epoch 310/400:  loss:0.336, accuracy-:0.844, val_loss:0.350, val_accuracy->0.825
# Epoch 320/400:  loss:0.336, accuracy-:0.843, val_loss:0.348, val_accuracy->0.820
# Epoch 330/400:  loss:0.336, accuracy-:0.843, val_loss:0.349, val_accuracy->0.823
# Epoch 340/400:  loss:0.336, accuracy-:0.842, val_loss:0.348, val_accuracy->0.824
# Epoch 350/400:  loss:0.336, accuracy-:0.842, val_loss:0.349, val_accuracy->0.827
# Epoch 360/400:  loss:0.336, accuracy-:0.843, val_loss:0.349, val_accuracy->0.823
# Epoch 370/400:  loss:0.336, accuracy-:0.843, val_loss:0.350, val_accuracy->0.822
# Epoch 380/400:  loss:0.336, accuracy-:0.843, val_loss:0.349, val_accuracy->0.824
# Epoch 390/400:  loss:0.336, accuracy-:0.843, val_loss:0.348, val_accuracy->0.823

# %%
regularized_val_history_df = pd.DataFrame(regularized_val_history)
regularized_train_history_df = pd.DataFrame(regularized_train_history)

# %%
plt.figure()
plt.plot(regularized_train_history_df["epoch"],regularized_train_history_df["loss"], label = "Regularized training set")
plt.plot(regularized_val_history_df["epoch"],regularized_val_history_df["loss"], label = "Regularized validation set")
plt.plot(train_history_df["epoch"],train_history_df["loss"], label = "Large training set")
plt.plot(val_history_df["epoch"],val_history_df["loss"], label = "Large validation set")
plt.title("Learning Curve")
plt.ylabel("Cross Entropy Loss")
plt.xlabel("Epoch")
plt.legend()

# %%
plt.figure()
plt.plot(regularized_train_history_df["epoch"],regularized_train_history_df["accuracy"], label = "Regularized training set")
plt.plot(regularized_val_history_df["epoch"],regularized_val_history_df["accuracy"], label = "Regularized validation set")
plt.plot(train_history_df["epoch"],train_history_df["accuracy"], label = "Large training set")
plt.plot(val_history_df["epoch"],val_history_df["accuracy"], label = "Large validation set")
plt.title("Learning Curve")
plt.ylabel("Accuracy")
plt.xlabel("Epoch")
plt.legend()
