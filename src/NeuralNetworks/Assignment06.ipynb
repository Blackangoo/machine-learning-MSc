# %% [markdown]
# # Pytorch tutorial
#
# In this tutorial we will cover some basic concepts of optimization using [Pytorch](https://pytorch.org/) machine learning library.
#
# We will go through
# 1. introduction to pytorch
# 2. Example of using gradient descent on simple function
# 3. Define and train Neural Networks for classification task
#
#
# some usefully links
# 1. pytorch documentation: https://pytorch.org/docs/stable/
# 2. pytorch tutorials: https://pytorch.org/tutorials/beginner/basics/intro.html

# %% [markdown]
# # 1. Introduction to Pytorch
#
# Pytorch is one of the most famous libraries to develop deep learning models.
#
# We will go thought the basic concepts pytorch while we will explain more as we move forward on the tutorial.
#
# We will use Pytorch version: '2.1.0'

# %%
# you can install torch by using the following command
# !pip install torch==2.1.0

# %%
# you can install torchsummary by using the following command
# !pip install torchsummary

# %%
import torch
import numpy as np
import matplotlib.pyplot as plt

# %%
torch.__version__
# Out:
# '2.1.0'

# %% [markdown]
# # Tensors
#
# Tensors is one of the fundamental componentes of pytorch.
# You can think of tensors as a numpy arrays.
#
# Using Tensors pytorch is able to create computational graphs and calculate the gradients.
#
# Tensors support different kind of operations listed in the following [link](https://pytorch.org/docs/stable/torch.html#pointwise-ops)
# Apart from the pytorch operators we can apply python operators between tensors.

# %%
tensor_1 = torch.tensor([[1., 2.], 
                         [3., 3.]])

tensor_2 = torch.tensor([[1., 0], 
                         [-1., 0]])

# %%
print("tensor_1 shape: ", tensor_1.shape)
print("tensor_2 shape: ", tensor_2.shape)
# Out:
# tensor_1 shape:  torch.Size([2, 2])
# tensor_2 shape:  torch.Size([2, 2])

# %%
elem_mul = tensor_1 * tensor_2
print("Element wise multiplication")
print("Result shape: ", elem_mul.size())
elem_mul
# Out:
# Element wise multiplication
# Result shape:  torch.Size([2, 2])
# tensor([[ 1.,  0.],
#         [-3.,  0.]])

# %%
matrix_mul = torch.matmul(tensor_1,tensor_2)
print("Matrix multiplication")
print("Result shape: ", matrix_mul.size())
torch.matmul(tensor_1,tensor_2)
# Out:
# Matrix multiplication
# Result shape:  torch.Size([2, 2])
# tensor([[-1.,  0.],
#         [ 0.,  0.]])

# %%
# get tensor as numpy array
tensor_1.data.numpy()
# Out:
# array([[1., 2.],
#        [3., 3.]], dtype=float32)

# %% [markdown]
# To begin lets define a simple polynomial function.

# %%
def f(x):
    """
    A convex function
    f(x) = (x-5)^2
    """
    y = (x-5)**2
    return y

# %%
x = torch.linspace(-5, 15,100)

plt.figure()
plt.plot(x, f(x), label = "(x-5)^2")
plt.legend()
plt.title("Convex function \n  f(x) = (x-5)^2")
plt.ylabel("y")
plt.xlabel("x")
plt.show()
plt.close()

# %% [markdown]
# The above function has the following computational graph
#
# <p align="center">
#   <img style="float: left;" src="./figures/Computational_Graph.png" width="500"/>
# </p>

# %% [markdown]
# The libraries that implement automatic differentiation keep track of the different operation between variables to construct the computational graph.
#
# Having this graph allows us to compute the gradients of complex function.
#
#
# Having a computational graph we have two main operation:
# 1. **Forward pass**: calculate the output of the computational graph. In our example the value of f(x)
# 2. **Backward pass**: calculate the gradients of each node in the computational graph.
#    Having the gradients of each node allows us to calculate the final gradient of each node using the chain rule of differentiation.In our example the df/dx.
#
#
# <p align="center">
#   <img style="float: left;" src="./figures/Auto_diff_Computational_Graph.png" width="900"/>
# </p>

# %%
# create tensors with requires_grad = true in order to indicate pytorch to track the gradients of the tensor.
x = torch.tensor(5.0, requires_grad = True)

# get the output of a function
y = f(x) # forward pass

# Compute gradients using backward function for y
y.backward()

# Access the gradients using x.grad
gradient = x.grad
print("gradient df(x)/dx|(x=5) :", gradient.data.numpy())
# Out:
# gradient df(x)/dx|(x=5) : 0.0

# %%
def grad_f(x):
    """
    return the gradient of the function evaluated at x.
    """
    grad = 2*(x-5)
    return grad

# %%
x = 5

print("f(x=5)=",f(x))
print("Analytic Gradient df/dx|(x=5)=", grad_f(5))
# Out:
# f(x=5)= 0
# Analytic Gradient df/dx|(x=5)= 0

# %% [markdown]
# # Gradient Decent
#
# **Gradient Descent (GD)** is a iterative method to find a minimum of a **convex function**.
#
# **Gradient descent** is one of the most popular algorithms to perform optimization and by far the most common way to optimize neural networks.
#
# In machine learning, Gradient descent is a way to minimize an objective function whit respect to model’s parameters by updating the parameters in the opposite direction of the gradient of the objective function w.r.t. to the parameters.
#
# <figure>
#   <img style="float: left;" src="./figures/Gradiend_descent.png" width="800"/>
# </figure>

# %% [markdown]
# ### Implement Gradient Descent
# in the following example we will find the minimum of a function using gradient decent.
#
#
# <figure>
#   <img style="float: left;" src="./figures/sgd.png" width="400"/>
# </figure>|

# %%
x_init= -13.0
thr = 0.0001
step_max = 500
lr = 0.1
min_value = 0

function = f

def gradient_decent(function, x_init, min_value, lr, step_max, thr):
    x = torch.tensor(x_init, requires_grad = True)
    
    x_history = [x.data]
    step = 0 
    while step < step_max:
        # step 1. Forward pass to get the output
        y = function(x)

        # step 2. Backward pass to calculate the gradient
        y.backward()

        # step 3. Update x to find minimum
        gradient = x.grad.data
        x.data = x.data - lr * gradient
        x.grad.data.zero_() # tenchical steps, otherwise accumulate the gradients

        # just keep the values of x
        x_history += [x.data]
        step = step +1
        
        # stoping critiria
        if abs(function(x.data) - function(x_history[-2])) < thr:
            break
    x_history = np.array(x_history)
    return x.data, step, x_history

# %%
x_min, total_steps, x_history = gradient_decent(function = f, 
                                                x_init = -3.0 ,
                                                min_value=0,
                                                lr = 0.1,
                                                step_max = 100,
                                                thr = 0.001)

# %%
print("Total steps to achive minimum:" , total_steps)
print("Minimum:" , x_min.data.numpy())
# Out:
# Total steps to achive minimum: 24
# Minimum: 4.962221

# %%
x_history = np.array(x_history)

# %%
x = np.linspace(-13, 23,100)
# x_history = np.array()
plt.figure()
plt.plot(x, f(x), label = "(x-5)^2")
plt.plot(x_history, f(x_history),marker = "o", color="r")
plt.legend()
plt.title("Convex function")
plt.ylabel("y")
plt.xlabel("x")
plt.show()
plt.close()

# %% [markdown]
# ### lr = 0.005

# %%
x_min, total_steps, x_history = gradient_decent(function = f, 
                                                x_init = -3.0 ,
                                                min_value=0,
                                                lr = 0.005,
                                                step_max = 100,
                                                thr = 0.001)

# %%
print("Total steps to achive minimum:" , total_steps)
print("Minimum:" , x_min.data.numpy())
# Out:
# Total steps to achive minimum: 100
# Minimum: 2.071741

# %%
x = np.linspace(-13, 23,100)
# x_history = np.array()
plt.figure()
plt.plot(x, f(x), label = "(x-5)^2")
plt.plot(x_history, f(x_history),marker = "o", color="r")
plt.legend()
plt.title("Convex function")
plt.ylabel("y")
plt.xlabel("x")
plt.show()
plt.close()

# %% [markdown]
# ### lr = 0.7

# %%
x_min, total_steps, x_history = gradient_decent(function = f, 
                                                x_init = -3.0 ,
                                                min_value=0,
                                                lr = 0.7,
                                                step_max = 100,
                                                thr = 0.001)

# %%
print("Total steps to achive minimum:" , total_steps)
print("Minimum:" , x_min.data.numpy())
# Out:
# Total steps to achive minimum: 7
# Minimum: 5.0131073

# %%
x = np.linspace(-13, 23,100)
# x_history = np.array()
plt.figure()
plt.plot(x, f(x), label = "(x-5)^2")
plt.plot(x_history, f(x_history),marker = "o", color="r")
plt.legend()
plt.title("Convex function")
plt.ylabel("y")
plt.xlabel("x")
plt.show()
plt.close()

# %% [markdown]
# ### lr = 1.1

# %%
x_min, total_steps, x_history = gradient_decent(function = f, 
                                                x_init = -3.0 ,
                                                min_value=0,
                                                lr = 1.1,
                                                step_max = 5,
                                                thr = 0.001)

# %%
x = np.linspace(-13, 23,100)
# x_history = np.array()
plt.figure()
plt.plot(x, f(x), label = "(x-5)^2")
plt.plot(x_history, f(x_history),marker = "o", color="r")
plt.legend()
plt.title("Convex function")
plt.ylabel("y")
plt.xlabel("x")
plt.show()
plt.close()

# %% [markdown]
# # Load Adult dataset

# %%
from collections import OrderedDict

data_types = OrderedDict([
    ("age", "int"),
    ("workclass", "category"),
    ("final_weight", "int"),  # originally it was called fnlwgt
    ("education", "category"),
    ("education_num", "int"),
    ("marital_status", "category"),
    ("occupation", "category"),
    ("relationship", "category"),
    ("race", "category"),
    ("sex", "category"),
    ("capital_gain", "float"),  # required because of NaN values
    ("capital_loss", "int"),
    ("hours_per_week", "int"),
    ("native_country", "category"),
    ("income_class", "category"),
])
target_column = "income_class"

# %%
def read_dataset(path):
    return pd.read_csv(
        path,
        names=data_types,
        index_col=None,

        comment='|',  # test dataset has comment in it
        skipinitialspace=True,  # Skip spaces after delimiter
        na_values={
            'capital_gain': 99999,
            'workclass': '?',
            'native_country': '?',
            'occupation': '?',
        },
        dtype=data_types,
    )

def clean_dataset(data):
    # Test dataset has dot at the end, we remove it in order
    # to unify names between training and test datasets.
    data['income_class'] = data.income_class.str.rstrip('.').astype('category')

    # Remove final weight column since there is no use
    # for it during the classification.
    data = data.drop('final_weight', axis=1)

    # Duplicates might create biases during the analysis and
    # during prediction stage they might give over-optimistic
    # (or pessimistic) results.
    data = data.drop_duplicates()

    # Binary target variable (>50K == 1 and <=50K == 0)
    data[target_column] = (data[target_column] == '>50K').astype(int)

    # Categorical dataset
    categorical_features = data.select_dtypes('category').columns
    data[categorical_features] = data.select_dtypes('category').apply(lambda x: x.cat.codes)
    return data

# %%
import pandas as pd
# get and clean train dataset
TRAIN_DATA_FILE = 'https://archive.ics.uci.edu/ml/machine-learning-databases/adult/adult.data'
train_data = clean_dataset(read_dataset(TRAIN_DATA_FILE))
train_data = train_data.dropna()
print("Train dataset shape:", train_data.shape)

# get and clean test dataset
TEST_DATA_FILE = 'https://archive.ics.uci.edu/ml/machine-learning-databases/adult/adult.test'
test_data = clean_dataset(read_dataset(TEST_DATA_FILE))
test_data = test_data.dropna()
print("Test dataset shape:", test_data.shape)
# Out:
# ---------------------------------------------------------------------------
# SSLError                                  Traceback (most recent call last)
# File ~/miniconda3/envs/MachineLearning/lib/python3.11/urllib/request.py:1348, in AbstractHTTPHandler.do_open(self, http_class, req, **http_conn_args)
#    1347 try:
# -> 1348     h.request(req.get_method(), req.selector, req.data, headers,
#    1349               encode_chunked=req.has_header('Transfer-encoding'))
#    1350 except OSError as err: # timeout error
#
# File ~/miniconda3/envs/MachineLearning/lib/python3.11/http/client.py:1286, in HTTPConnection.request(self, method, url, body, headers, encode_chunked)
#    1285 """Send a complete request to the server."""
# -> 1286 self._send_request(method, url, body, headers, encode_chunked)
#
# File ~/miniconda3/envs/MachineLearning/lib/python3.11/http/client.py:1332, in HTTPConnection._send_request(self, method, url, body, headers, encode_chunked)
#    1331     body = _encode(body, 'body')
# -> 1332 self.endheaders(body, encode_chunked=encode_chunked)
#
# File ~/miniconda3/envs/MachineLearning/lib/python3.11/http/client.py:1281, in HTTPConnection.endheaders(self, message_body, encode_chunked)
#    1280     raise CannotSendHeader()
# -> 1281 self._send_output(message_body, encode_chunked=encode_chunked)
#
# File ~/miniconda3/envs/MachineLearning/lib/python3.11/http/client.py:1041, in HTTPConnection._send_output(self, message_body, encode_chunked)
#    1040 del self._buffer[:]
# -> 1041 self.send(msg)
#    1043 if message_body is not None:
#    1044
#    1045     # create a consistent interface to message_body
#
# File ~/miniconda3/envs/MachineLearning/lib/python3.11/http/client.py:979, in HTTPConnection.send(self, data)
#     978 if self.auto_open:
# --> 979     self.connect()
#     980 else:
#
# File ~/miniconda3/envs/MachineLearning/lib/python3.11/http/client.py:1458, in HTTPSConnection.connect(self)
#    1456     server_hostname = self.host
# -> 1458 self.sock = self._context.wrap_socket(self.sock,
#    1459                                       server_hostname=server_hostname)
#
# File ~/miniconda3/envs/MachineLearning/lib/python3.11/ssl.py:517, in SSLContext.wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, session)
#     511 def wrap_socket(self, sock, server_side=False,
#     512                 do_handshake_on_connect=True,
#     513                 suppress_ragged_eofs=True,
#     514                 server_hostname=None, session=None):
#     515     # SSLSocket class handles server_hostname encoding before it calls
#     516     # ctx._wrap_socket()
# --> 517     return self.sslsocket_class._create(
#     518         sock=sock,
#     519         server_side=server_side,
#     520         do_handshake_on_connect=do_handshake_on_connect,
#     521         suppress_ragged_eofs=suppress_ragged_eofs,
#     522         server_hostname=server_hostname,
#     523         context=self,
#     524         session=session
#     525     )
#
# File ~/miniconda3/envs/MachineLearning/lib/python3.11/ssl.py:1075, in SSLSocket._create(cls, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, context, session)
#    1074             raise ValueError("do_handshake_on_connect should not be specified for non-blocking sockets")
# -> 1075         self.do_handshake()
#    1076 except (OSError, ValueError):
#
# File ~/miniconda3/envs/MachineLearning/lib/python3.11/ssl.py:1346, in SSLSocket.do_handshake(self, block)
#    1345         self.settimeout(None)
# -> 1346     self._sslobj.do_handshake()
#    1347 finally:
#
# SSLError: [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed (_ssl.c:1002)
#
# During handling of the above exception, another exception occurred:
#
# URLError                                  Traceback (most recent call last)
# /home/blackangoo/University/MachineLearning/machine-learning-MSc/src/NeuralNetworks/Assignment06.ipynb Cellule 42 line 4
#       <a href='vscode-notebook-cell://wsl%2Bubuntu/home/blackangoo/University/MachineLearning/machine-learning-MSc/src/NeuralNetworks/Assignment06.ipynb#X56sdnNjb2RlLXJlbW90ZQ%3D%3D?line=1'>2</a> # get and clean train dataset
#       <a href='vscode-notebook-cell://wsl%2Bubuntu/home/blackangoo/University/MachineLearning/machine-learning-MSc/src/NeuralNetworks/Assignment06.ipynb#X56sdnNjb2RlLXJlbW90ZQ%3D%3D?line=2'>3</a> TRAIN_DATA_FILE = 'https://archive.ics.uci.edu/ml/machine-learning-databases/adult/adult.data'
# ----> <a href='vscode-notebook-cell://wsl%2Bubuntu/home/blackangoo/University/MachineLearning/machine-learning-MSc/src/NeuralNetworks/Assignment06.ipynb#X56sdnNjb2RlLXJlbW90ZQ%3D%3D?line=3'>4</a> train_data = clean_dataset(read_dataset(TRAIN_DATA_FILE))
#       <a href='vscode-notebook-cell://wsl%2Bubuntu/home/blackangoo/University/MachineLearning/machine-learning-MSc/src/NeuralNetworks/Assignment06.ipynb#X56sdnNjb2RlLXJlbW90ZQ%3D%3D?line=4'>5</a> train_data = train_data.dropna()
#       <a href='vscode-notebook-cell://wsl%2Bubuntu/home/blackangoo/University/MachineLearning/machine-learning-MSc/src/NeuralNetworks/Assignment06.ipynb#X56sdnNjb2RlLXJlbW90ZQ%3D%3D?line=5'>6</a> print("Train dataset shape:", train_data.shape)
#
# /home/blackangoo/University/MachineLearning/machine-learning-MSc/src/NeuralNetworks/Assignment06.ipynb Cellule 42 line 2
#       <a href='vscode-notebook-cell://wsl%2Bubuntu/home/blackangoo/University/MachineLearning/machine-learning-MSc/src/NeuralNetworks/Assignment06.ipynb#X56sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> def read_dataset(path):
# ----> <a href='vscode-notebook-cell://wsl%2Bubuntu/home/blackangoo/University/MachineLearning/machine-learning-MSc/src/NeuralNetworks/Assignment06.ipynb#X56sdnNjb2RlLXJlbW90ZQ%3D%3D?line=1'>2</a>     return pd.read_csv(
#       <a href='vscode-notebook-cell://wsl%2Bubuntu/home/blackangoo/University/MachineLearning/machine-learning-MSc/src/NeuralNetworks/Assignment06.ipynb#X56sdnNjb2RlLXJlbW90ZQ%3D%3D?line=2'>3</a>         path,
#       <a href='vscode-notebook-cell://wsl%2Bubuntu/home/blackangoo/University/MachineLearning/machine-learning-MSc/src/NeuralNetworks/Assignment06.ipynb#X56sdnNjb2RlLXJlbW90ZQ%3D%3D?line=3'>4</a>         names=data_types,
#       <a href='vscode-notebook-cell://wsl%2Bubuntu/home/blackangoo/University/MachineLearning/machine-learning-MSc/src/NeuralNetworks/Assignment06.ipynb#X56sdnNjb2RlLXJlbW90ZQ%3D%3D?line=4'>5</a>         index_col=None,
#       <a href='vscode-notebook-cell://wsl%2Bubuntu/home/blackangoo/University/MachineLearning/machine-learning-MSc/src/NeuralNetworks/Assignment06.ipynb#X56sdnNjb2RlLXJlbW90ZQ%3D%3D?line=5'>6</a>
#       <a href='vscode-notebook-cell://wsl%2Bubuntu/home/blackangoo/University/MachineLearning/machine-learning-MSc/src/NeuralNetworks/Assignment06.ipynb#X56sdnNjb2RlLXJlbW90ZQ%3D%3D?line=6'>7</a>         comment='|',  # test dataset has comment in it
#       <a href='vscode-notebook-cell://wsl%2Bubuntu/home/blackangoo/University/MachineLearning/machine-learning-MSc/src/NeuralNetworks/Assignment06.ipynb#X56sdnNjb2RlLXJlbW90ZQ%3D%3D?line=7'>8</a>         skipinitialspace=True,  # Skip spaces after delimiter
#       <a href='vscode-notebook-cell://wsl%2Bubuntu/home/blackangoo/University/MachineLearning/machine-learning-MSc/src/NeuralNetworks/Assignment06.ipynb#X56sdnNjb2RlLXJlbW90ZQ%3D%3D?line=8'>9</a>         na_values={
#      <a href='vscode-notebook-cell://wsl%2Bubuntu/home/blackangoo/University/MachineLearning/machine-learning-MSc/src/NeuralNetworks/Assignment06.ipynb#X56sdnNjb2RlLXJlbW90ZQ%3D%3D?line=9'>10</a>             'capital_gain': 99999,
#      <a href='vscode-notebook-cell://wsl%2Bubuntu/home/blackangoo/University/MachineLearning/machine-learning-MSc/src/NeuralNetworks/Assignment06.ipynb#X56sdnNjb2RlLXJlbW90ZQ%3D%3D?line=10'>11</a>             'workclass': '?',
#      <a href='vscode-notebook-cell://wsl%2Bubuntu/home/blackangoo/University/MachineLearning/machine-learning-MSc/src/NeuralNetworks/Assignment06.ipynb#X56sdnNjb2RlLXJlbW90ZQ%3D%3D?line=11'>12</a>             'native_country': '?',
#      <a href='vscode-notebook-cell://wsl%2Bubuntu/home/blackangoo/University/MachineLearning/machine-learning-MSc/src/NeuralNetworks/Assignment06.ipynb#X56sdnNjb2RlLXJlbW90ZQ%3D%3D?line=12'>13</a>             'occupation': '?',
#      <a href='vscode-notebook-cell://wsl%2Bubuntu/home/blackangoo/University/MachineLearning/machine-learning-MSc/src/NeuralNetworks/Assignment06.ipynb#X56sdnNjb2RlLXJlbW90ZQ%3D%3D?line=13'>14</a>         },
#      <a href='vscode-notebook-cell://wsl%2Bubuntu/home/blackangoo/University/MachineLearning/machine-learning-MSc/src/NeuralNetworks/Assignment06.ipynb#X56sdnNjb2RlLXJlbW90ZQ%3D%3D?line=14'>15</a>         dtype=data_types,
#      <a href='vscode-notebook-cell://wsl%2Bubuntu/home/blackangoo/University/MachineLearning/machine-learning-MSc/src/NeuralNetworks/Assignment06.ipynb#X56sdnNjb2RlLXJlbW90ZQ%3D%3D?line=15'>16</a>     )
#
# File ~/miniconda3/envs/MachineLearning/lib/python3.11/site-packages/pandas/io/parsers/readers.py:948, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     935 kwds_defaults = _refine_defaults_read(
#     936     dialect,
#     937     delimiter,
#    (...)
#     944     dtype_backend=dtype_backend,
#     945 )
#     946 kwds.update(kwds_defaults)
# --> 948 return _read(filepath_or_buffer, kwds)
#
# File ~/miniconda3/envs/MachineLearning/lib/python3.11/site-packages/pandas/io/parsers/readers.py:611, in _read(filepath_or_buffer, kwds)
#     608 _validate_names(kwds.get("names", None))
#     610 # Create the parser.
# --> 611 parser = TextFileReader(filepath_or_buffer, **kwds)
#     613 if chunksize or iterator:
#     614     return parser
#
# File ~/miniconda3/envs/MachineLearning/lib/python3.11/site-packages/pandas/io/parsers/readers.py:1448, in TextFileReader.__init__(self, f, engine, **kwds)
#    1445     self.options["has_index_names"] = kwds["has_index_names"]
#    1447 self.handles: IOHandles | None = None
# -> 1448 self._engine = self._make_engine(f, self.engine)
#
# File ~/miniconda3/envs/MachineLearning/lib/python3.11/site-packages/pandas/io/parsers/readers.py:1705, in TextFileReader._make_engine(self, f, engine)
#    1703     if "b" not in mode:
#    1704         mode += "b"
# -> 1705 self.handles = get_handle(
#    1706     f,
#    1707     mode,
#    1708     encoding=self.options.get("encoding", None),
#    1709     compression=self.options.get("compression", None),
#    1710     memory_map=self.options.get("memory_map", False),
#    1711     is_text=is_text,
#    1712     errors=self.options.get("encoding_errors", "strict"),
#    1713     storage_options=self.options.get("storage_options", None),
#    1714 )
#    1715 assert self.handles is not None
#    1716 f = self.handles.handle
#
# File ~/miniconda3/envs/MachineLearning/lib/python3.11/site-packages/pandas/io/common.py:718, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     715     codecs.lookup_error(errors)
#     717 # open URLs
# --> 718 ioargs = _get_filepath_or_buffer(
#     719     path_or_buf,
#     720     encoding=encoding,
#     721     compression=compression,
#     722     mode=mode,
#     723     storage_options=storage_options,
#     724 )
#     726 handle = ioargs.filepath_or_buffer
#     727 handles: list[BaseBuffer]
#
# File ~/miniconda3/envs/MachineLearning/lib/python3.11/site-packages/pandas/io/common.py:372, in _get_filepath_or_buffer(filepath_or_buffer, encoding, compression, mode, storage_options)
#     370 # assuming storage_options is to be interpreted as headers
#     371 req_info = urllib.request.Request(filepath_or_buffer, headers=storage_options)
# --> 372 with urlopen(req_info) as req:
#     373     content_encoding = req.headers.get("Content-Encoding", None)
#     374     if content_encoding == "gzip":
#     375         # Override compression based on Content-Encoding header
#
# File ~/miniconda3/envs/MachineLearning/lib/python3.11/site-packages/pandas/io/common.py:274, in urlopen(*args, **kwargs)
#     268 """
#     269 Lazy-import wrapper for stdlib urlopen, as that imports a big chunk of
#     270 the stdlib.
#     271 """
#     272 import urllib.request
# --> 274 return urllib.request.urlopen(*args, **kwargs)
#
# File ~/miniconda3/envs/MachineLearning/lib/python3.11/urllib/request.py:216, in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     214 else:
#     215     opener = _opener
# --> 216 return opener.open(url, data, timeout)
#
# File ~/miniconda3/envs/MachineLearning/lib/python3.11/urllib/request.py:519, in OpenerDirector.open(self, fullurl, data, timeout)
#     516     req = meth(req)
#     518 sys.audit('urllib.Request', req.full_url, req.data, req.headers, req.get_method())
# --> 519 response = self._open(req, data)
#     521 # post-process response
#     522 meth_name = protocol+"_response"
#
# File ~/miniconda3/envs/MachineLearning/lib/python3.11/urllib/request.py:536, in OpenerDirector._open(self, req, data)
#     533     return result
#     535 protocol = req.type
# --> 536 result = self._call_chain(self.handle_open, protocol, protocol +
#     537                           '_open', req)
#     538 if result:
#     539     return result
#
# File ~/miniconda3/envs/MachineLearning/lib/python3.11/urllib/request.py:496, in OpenerDirector._call_chain(self, chain, kind, meth_name, *args)
#     494 for handler in handlers:
#     495     func = getattr(handler, meth_name)
# --> 496     result = func(*args)
#     497     if result is not None:
#     498         return result
#
# File ~/miniconda3/envs/MachineLearning/lib/python3.11/urllib/request.py:1391, in HTTPSHandler.https_open(self, req)
#    1390 def https_open(self, req):
# -> 1391     return self.do_open(http.client.HTTPSConnection, req,
#    1392         context=self._context, check_hostname=self._check_hostname)
#
# File ~/miniconda3/envs/MachineLearning/lib/python3.11/urllib/request.py:1351, in AbstractHTTPHandler.do_open(self, http_class, req, **http_conn_args)
#    1348         h.request(req.get_method(), req.selector, req.data, headers,
#    1349                   encode_chunked=req.has_header('Transfer-encoding'))
#    1350     except OSError as err: # timeout error
# -> 1351         raise URLError(err)
#    1352     r = h.getresponse()
#    1353 except:
#
# URLError: <urlopen error [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed (_ssl.c:1002)>

# %%
target_column = "income_class"
features = train_data.columns.difference([target_column])
sensitive_feature = ["sex"]
non_sensitive_features = list(set(features).difference(set(sensitive_feature)))

# %%
from sklearn.model_selection import train_test_split
X_train, X_val, y_train, y_val = train_test_split(train_data[features], train_data[[target_column]], test_size=0.1)
X_test, y_test = test_data[features], test_data[[target_column]]

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_train = pd.DataFrame(scaler.fit_transform(X_train),columns = features)
X_val = pd.DataFrame(scaler.transform(X_val),columns = features)
X_test = pd.DataFrame(scaler.transform(X_test),columns = features)
# Out:
# /home/blackangoo/miniconda3/envs/MachineLearning/lib/python3.11/site-packages/sklearn/utils/validation.py:767: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if not hasattr(array, "sparse") and array.dtypes.apply(is_sparse).any():
# /home/blackangoo/miniconda3/envs/MachineLearning/lib/python3.11/site-packages/sklearn/utils/validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# /home/blackangoo/miniconda3/envs/MachineLearning/lib/python3.11/site-packages/sklearn/utils/validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):
# /home/blackangoo/miniconda3/envs/MachineLearning/lib/python3.11/site-packages/sklearn/utils/validation.py:767: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if not hasattr(array, "sparse") and array.dtypes.apply(is_sparse).any():
# /home/blackangoo/miniconda3/envs/MachineLearning/lib/python3.11/site-packages/sklearn/utils/validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# /home/blackangoo/miniconda3/envs/MachineLearning/lib/python3.11/site-packages/sklearn/utils/validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):
# /home/blackangoo/miniconda3/envs/MachineLearning/lib/python3.11/site-packages/sklearn/utils/validation.py:767: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if not hasattr(array, "sparse") and array.dtypes.apply(is_sparse).any():
# /home/blackangoo/miniconda3/envs/MachineLearning/lib/python3.11/site-packages/sklearn/utils/validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# /home/blackangoo/miniconda3/envs/MachineLearning/lib/python3.11/site-packages/sklearn/utils/validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):
# /home/blackangoo/miniconda3/envs/MachineLearning/lib/python3.11/site-packages/sklearn/utils/validation.py:767: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if not hasattr(array, "sparse") and array.dtypes.apply(is_sparse).any():
# /home/blackangoo/miniconda3/envs/MachineLearning/lib/python3.11/site-packages/sklearn/utils/validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# /home/blackangoo/miniconda3/envs/MachineLearning/lib/python3.11/site-packages/sklearn/utils/validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):

# %%
X_train.shape, X_val.shape, X_test.shape
# Out:
# ((26044, 13), (2894, 13), (15175, 13))

# %% [markdown]
# # Neural Networks
#
# Neural Networks are powerful function approximator that archives state-of-the-art performance on a lot of application the last decade on machine learning.
#
# The performance of the Deep Neural Network's is due to their high number of parameters and the efficient learning methods used to train those networks.
# For example the gtp-3 languages model was about by 175 billion parameters.
#
# Neural Networks, adjust their parameters (training), using the gradient descent method to **minimise a loss function** $L$.

# %% [markdown]
# <figure>
#   <img style="float: left;" src="./figures/neural_net_new.png" width="800"/>
# </figure>|

# %% [markdown]
# ### Operation of each node

# %% [markdown]
# <figure>
#   <img style="float: left;" src="./figures/neuron_2.png" width="600"/>
# </figure>

# %% [markdown]
# # Activation Functions
#
# Activation functions play an integral role in neural networks by introducing non-linearity.
# This non-linearity allows neural networks to develop complex representations and functions based on the inputs that would not be possible with a simple linear layers.
#
# Bellow we illustrate some of the most famous activation functions

# %% [markdown]
# <figure>
#   <img style="float: left;" src="./figures/acitvation_fun.png" width="600"/>
# </figure>

# %% [markdown]
# # Classification problem
#
# In classification problem the output of the neural network can be probability of each class p(y|x).
#
# So for binary classification we can do that using a single output to indicate the p(y=1|x).
# This has to be bounded between [0,1] in order to be a probability.
# To do so we can use the sigmoid function that we can illustrate bellow.
#
# <figure>
#   <img style="float: left;" src="./figures/sigmoid.png" width="400"/>
# </figure>

# %% [markdown]
# Then we can use the binary cross entropy loss as the **loss function**
#
# <figure>
#   <img style="float: left;" src="./figures/binary_ce.png" width="400"/>
# </figure>

# %% [markdown]
# Where
# $$\hat{Y} = f(x) = p(y=1|x)$$

# %% [markdown]
# As a note, for regression problem we don't use activation function in the final layer, while loss function is usually the mean square error.

# %% [markdown]
# # Define Neural Network with pytorch
#
# We will implement a simple neural network for classification problem with pytorch.
# The following network has 2 hidden layers following by an output layer.

# %%
class NeuralNetwork(torch.nn.Module):
    """
    Simple two layer neural network for regression
    """
    def __init__(self, num_input_features):
        super().__init__()
        
        # layer 1
        layer_1_units = 200
        self.layer_1 = torch.nn.Linear(in_features=num_input_features,
                                       out_features=layer_1_units)
        self.activation_1 = torch.nn.ReLU()
        
        # layer  2
        layer_2_units = 100
        self.layer_2 = torch.nn.Linear(in_features=layer_1_units,
                                       out_features=layer_2_units)
        self.activation_2 = torch.nn.ReLU()
        
        # layer output layer
        self.out_layer = torch.nn.Linear(in_features=layer_2_units,
                                         out_features=1)
        self.out_activation= torch.nn.Sigmoid()

    def forward(self, x):
        x_1 = self.activation_1( self.layer_1( x ) )
        x_2 = self.activation_2( self.layer_2( x_1 ) )
        output = self.out_activation(self.out_layer(x_2))
        return output

# %%
from torchsummary import summary
model = NeuralNetwork(num_input_features=12)
summary(model, input_size= [[12]])
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Linear-1                  [-1, 200]           2,600
#               ReLU-2                  [-1, 200]               0
#             Linear-3                  [-1, 100]          20,100
#               ReLU-4                  [-1, 100]               0
#             Linear-5                    [-1, 1]             101
#            Sigmoid-6                    [-1, 1]               0
# ================================================================
# Total params: 22,801
# Trainable params: 22,801
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.00
# Params size (MB): 0.09
# Estimated Total Size (MB): 0.09
# ----------------------------------------------------------------

# %% [markdown]
# ### make predictions

# %%
x = torch.rand((100,12))
y = torch.randint(0, 1, (100,1))
                  
predicted_proba = model.forward(x)

# %%
predicted_proba.shape # p(y=1|x)
# Out:
# torch.Size([100, 1])

# %%
predicted_proba
# Out:
# tensor([[0.4537],
#         [0.4575],
#         [0.4561],
#         [0.4653],
#         [0.4596],
#         [0.4556],
#         [0.4659],
#         [0.4589],
#         [0.4617],
#         [0.4616],
#         [0.4585],
#         [0.4560],
#         [0.4534],
#         [0.4597],
#         [0.4607],
#         [0.4626],
#         [0.4496],
#         [0.4591],
#         [0.4500],
#         [0.4584],
#         [0.4679],
#         [0.4605],
#         [0.4639],
#         [0.4736],
#         [0.4587],
#         [0.4569],
#         [0.4581],
#         [0.4699],
#         [0.4564],
#         [0.4660],
#         [0.4650],
#         [0.4600],
#         [0.4545],
#         [0.4574],
#         [0.4601],
#         [0.4519],
#         [0.4580],
#         [0.4683],
#         [0.4622],
#         [0.4574],
#         [0.4599],
#         [0.4507],
#         [0.4481],
#         [0.4617],
#         [0.4563],
#         [0.4557],
#         [0.4509],
#         [0.4603],
#         [0.4613],
#         [0.4560],
#         [0.4576],
#         [0.4489],
#         [0.4527],
#         [0.4629],
#         [0.4541],
#         [0.4666],
#         [0.4544],
#         [0.4612],
#         [0.4605],
#         [0.4557],
#         [0.4688],
#         [0.4610],
#         [0.4612],
#         [0.4563],
#         [0.4603],
#         [0.4569],
#         [0.4587],
#         [0.4699],
#         [0.4648],
#         [0.4544],
#         [0.4483],
#         [0.4649],
#         [0.4521],
#         [0.4656],
#         [0.4561],
#         [0.4611],
#         [0.4498],
#         [0.4531],
#         [0.4742],
#         [0.4708],
#         [0.4652],
#         [0.4576],
#         [0.4599],
#         [0.4641],
#         [0.4571],
#         [0.4471],
#         [0.4569],
#         [0.4607],
#         [0.4656],
#         [0.4697],
#         [0.4521],
#         [0.4553],
#         [0.4532],
#         [0.4551],
#         [0.4594],
#         [0.4576],
#         [0.4549],
#         [0.4630],
#         [0.4633],
#         [0.4649]], grad_fn=<SigmoidBackward0>)

# %% [markdown]
# ### optimise network
# perfom a single iteration of sgd.

# %%
model = NeuralNetwork(num_input_features=12)

# to make the optimization pytorch has different optimizers. 
lr = 0.01
optimizer = torch.optim.SGD(model.parameters(), lr=lr)
loss_fn = torch.nn.BCELoss()

# %%
model.layer_2.weight
# Out:
# Parameter containing:
# tensor([[ 0.0500, -0.0182,  0.0468,  ...,  0.0234,  0.0112, -0.0476],
#         [-0.0189,  0.0421,  0.0006,  ...,  0.0238, -0.0488,  0.0262],
#         [-0.0039,  0.0485, -0.0427,  ...,  0.0216,  0.0364, -0.0474],
#         ...,
#         [ 0.0410,  0.0420, -0.0085,  ...,  0.0599, -0.0177, -0.0683],
#         [-0.0286,  0.0022,  0.0692,  ..., -0.0206,  0.0446,  0.0366],
#         [ 0.0024, -0.0210,  0.0555,  ..., -0.0272,  0.0619, -0.0471]],
#        requires_grad=True)

# %%
x = torch.rand((100, 12))
y = torch.randint(0, 1, (100, 1), dtype = torch.float)
                  
predicted_proba = model.forward(x)
loss = loss_fn(predicted_proba, y)
                  
loss.backward()
optimizer.step() # the optimiser aply the gradients to change the weights.

optimizer.zero_grad() # reset the gradients

# %%
model.layer_2.weight
# Out:
# Parameter containing:
# tensor([[ 0.0501, -0.0182,  0.0468,  ...,  0.0234,  0.0112, -0.0476],
#         [-0.0189,  0.0421,  0.0006,  ...,  0.0238, -0.0488,  0.0262],
#         [-0.0039,  0.0485, -0.0427,  ...,  0.0216,  0.0364, -0.0474],
#         ...,
#         [ 0.0410,  0.0420, -0.0085,  ...,  0.0599, -0.0177, -0.0683],
#         [-0.0288,  0.0022,  0.0692,  ..., -0.0206,  0.0446,  0.0366],
#         [ 0.0024, -0.0210,  0.0555,  ..., -0.0272,  0.0619, -0.0471]],
#        requires_grad=True)

# %% [markdown]
# # Batching data
#
# When we train neural network we usually train our model using batches of training example.
#
#
# <figure>
#   <img style="float: left;" src="./figures/batches.png" width="500"/>
# </figure>
#
#
#
# Batching method is performed for different reasons.
# First of all in we have a huge dataset we cannot fit all the data in our memery.
# Moreover, using batches requires less time to fit the model as in the same time you can perform more update in the weights of the model. One drawback of using batches is that we approximate the gradient directions, so having very small batch size can affect the coverage of your model.
#
# So batch size is an additional hyperparameter of our training algorithm.

# %% [markdown]
# <figure>
#   <img style="float: left;" src="./figures/train_loop.png" width="500"/>
# </figure>

# %% [markdown]
# lets use pytorch to batch our data.
#
# In summary PyTorch provides two main data classes: **DataLoader** and **Dataset** to handle your data.
#
# **Dataset**  stores the samples and their corresponding labels, and **DataLoader** wraps an iterable around the Dataset to enable easy access to the batches.
#
# you can read more at: https://pytorch.org/tutorials/beginner/basics/data_tutorial.html

# %%
# covert data into tensors
train_x_tensor = torch.tensor(X_train.values, dtype=torch.float)
train_y_tensor = torch.tensor(y_train.values, dtype=torch.float)

# use the dataset class wrapper for tensors
train_tensor_dataset = torch.utils.data.TensorDataset(train_x_tensor, train_y_tensor)# there are more coplex dataset
                                                                                     # i.e images or text data

# pass the dataset class into Dataloader to batch and shuffle your data
train_dataloader = torch.utils.data.DataLoader(train_tensor_dataset,
                                               batch_size=64,
                                               shuffle=True)

# %%
for batch in enumerate(train_dataloader):
    batch_x, batch_y = next(iter(train_dataloader)) # get next iteam
batch_x.shape
# Out:
# torch.Size([64, 13])

# %%
batch_x
# Out:
# tensor([[-1.4799, -0.2430, -0.2310, -2.3543, -1.1721, -0.0460,  0.9164,  0.3093,
#           0.3183,  0.4151, -0.2956, -1.3929,  0.0844],
#         [ 0.7907, -0.2430,  4.2440, -0.8205,  0.7235, -0.0460, -0.3837,  0.3093,
#          -0.8617,  0.4151, -0.9103,  0.7179,  0.0844],
#         [-0.2347, -0.2430, -0.2310, -0.0537,  2.2400,  0.7397, -0.3837, -4.2047,
#           0.7902,  0.4151, -0.9103,  0.7179,  0.0844],
#         [ 0.3512, -0.2430, -0.2310,  0.2019, -0.4139, -0.0460,  0.9164,  0.3093,
#          -1.3336,  0.4151,  1.5483, -1.3929, -1.9171],
#         [-0.6742, -0.2430, -0.2310,  0.4576,  1.4818, -1.8531, -0.3837, -0.0567,
#           0.7902, -2.9698, -0.9103,  0.7179,  2.0859],
#         [-0.0150, -0.2430, -0.2310, -0.3093,  1.1026,  0.3469, -0.3837,  0.3093,
#          -0.8617,  0.4151, -0.9103,  0.7179,  0.0844],
#         [ 0.4977, -0.2430, -0.2310, -0.3093,  1.1026,  0.3469,  0.9164,  0.3093,
#           1.2622,  0.4151, -0.2956,  0.7179,  0.0844],
#         [ 1.9626, -0.2430, -0.2310, -0.3093,  1.1026, -1.3031, -0.3837,  0.3093,
#          -1.5696,  0.4151, -0.9103,  0.7179, -2.5842],
#         [ 1.2302, -0.2430, -0.2310,  1.2244, -0.0347, -0.4388, -1.6837,  0.3093,
#          -1.3336,  0.4151, -0.2956, -1.3929, -1.2499],
#         [ 0.2047, -0.2430, -0.2310,  0.2019, -0.4139,  0.5826, -0.3837,  0.3093,
#           0.7902,  0.4151, -0.9103,  0.7179,  0.0844],
#         [ 2.2556, -0.2430, -0.2310,  0.2019, -0.4139, -1.9316, -0.3837,  0.3093,
#          -0.6257,  0.4151, -0.9103,  0.7179,  0.7516],
#         [-0.9672, -0.2430, -0.2310, -0.3093,  1.1026,  1.1326, -0.3837,  0.3093,
#          -0.6257,  0.4151, -0.9103,  0.7179,  0.0844],
#         [ 0.7907, -0.2430, -0.2310,  0.2019, -0.4139, -0.0460,  2.2165,  0.3093,
#           1.7342,  0.4151,  1.5483, -1.3929, -1.2499],
#         [-1.0404, -0.2430, -0.2310,  1.2244, -0.0347, -1.4602,  0.9164,  0.3093,
#           0.3183,  0.4151, -0.2956, -1.3929,  1.4187],
#         [-0.8207, -0.2430, -0.2310, -0.3093,  1.1026, -0.0460,  0.9164,  0.3093,
#           0.0823,  0.4151, -0.2956,  0.7179,  0.0844],
#         [ 0.4977, -0.2430, -0.2310,  1.2244, -0.0347, -2.4030, -0.3837,  0.3093,
#           0.7902,  0.4151, -0.9103,  0.7179,  0.0844],
#         [ 0.3512, -0.2430, -0.2310, -0.3093,  1.1026, -0.4388, -0.3837,  0.3093,
#           0.7902,  0.4151, -0.9103,  0.7179,  0.0844],
#         [-0.3080, -0.2430, -0.2310,  1.2244, -0.0347,  2.3111, -1.6837,  0.3093,
#          -0.6257,  0.4151, -0.2956, -1.3929,  0.0844],
#         [-0.4545, -0.2430, -0.2310,  1.2244, -0.0347,  0.7397,  0.9164,  0.3093,
#          -0.6257,  0.4151, -0.2956,  0.7179, -1.9171],
#         [ 1.5964, -0.2430, -0.2310,  0.2019, -0.4139, -0.0460, -0.3837,  0.3093,
#          -1.5696,  0.4151, -0.9103,  0.7179, -2.5842],
#         [-1.2602, -0.2430, -0.2310,  1.2244, -0.0347, -1.6174,  0.9164,  0.3093,
#           0.7902,  0.4151,  1.5483, -1.3929,  0.0844],
#         [ 1.9626, -0.2430, -0.2310,  1.2244, -0.0347,  0.3469, -0.3837,  0.3093,
#          -0.6257,  0.4151, -0.9103,  0.7179,  0.0844],
#         [ 0.0582, -0.2430, -0.2310, -1.5874, -2.6886, -0.0460, -0.3837, -1.2767,
#           0.3183,  0.4151, -0.9103,  0.7179,  0.0844],
#         [ 0.2047,  5.3208, -0.2310, -0.5649,  0.3444,  1.1326, -0.3837,  0.3093,
#          -0.6257,  0.4151, -0.9103,  0.7179,  0.0844],
#         [-0.2347, -0.2430, -0.2310,  1.2244, -0.0347,  1.5254, -0.3837,  0.3093,
#          -0.6257,  0.4151, -0.9103,  0.7179,  0.0844],
#         [-1.1137, -0.2430, -0.2310, -0.5649,  0.3444, -0.0460,  0.9164,  0.3093,
#           1.7342,  0.4151, -0.2956,  0.7179,  0.0844],
#         [ 0.1315, -0.2430, -0.2310,  0.2019, -0.4139,  0.3469, -1.6837,  0.3093,
#          -0.6257,  0.4151,  1.5483, -1.3929,  2.0859],
#         [-0.0882,  0.8047, -0.2310,  0.2019, -0.4139, -0.8317, -0.3837, -1.2767,
#          -0.1537,  0.4151, -0.9103,  0.7179,  0.0844],
#         [ 0.4245, -0.2430, -0.2310,  0.2019, -0.4139, -0.0460,  0.9164,  0.3093,
#           1.2622, -1.8415, -0.2956,  0.7179,  0.0844],
#         [ 0.8640, -0.2430, -0.2310,  0.2019, -0.4139, -0.0460,  0.9164,  0.3093,
#          -0.8617,  0.4151, -0.2956,  0.7179,  0.0844],
#         [-1.4799, -0.2430, -0.2310,  1.2244, -0.0347, -2.4030,  0.9164,  0.3093,
#           0.3183,  0.4151,  0.9336, -1.3929,  0.0844],
#         [ 2.5486, -0.2430, -0.2310,  0.9688,  1.8609, -0.0460, -1.6837,  0.3093,
#           0.7902,  0.4151,  0.3190,  0.7179,  1.4187],
#         [-0.6742, -0.2430, -0.2310,  1.2244, -0.0347,  2.3111, -0.3837,  0.3093,
#          -0.6257,  0.4151, -0.9103,  0.7179,  0.7516],
#         [-0.2347, -0.2430, -0.2310,  1.2244, -0.0347,  0.7397,  0.9164,  0.3093,
#           1.2622,  0.4151, -0.2956,  0.7179,  0.0844],
#         [-1.2602, -0.2430, -0.2310,  0.2019, -0.4139, -0.0460,  0.9164,  0.3093,
#          -1.3336,  0.4151,  1.5483,  0.7179,  0.0844],
#         [-0.0882, -0.2430, -0.2310, -1.3318, -2.3095, -0.0460, -1.6837,  0.3093,
#           1.2622,  0.4151,  1.5483, -1.3929,  0.0844],
#         [-0.8939, -0.2430, -0.2310,  0.2019, -0.4139, -0.0460,  0.9164,  0.3093,
#           0.3183, -1.8415,  1.5483, -1.3929,  0.0844],
#         [-0.7475, -0.2430, -0.2310,  1.2244, -0.0347, -0.0460,  1.5664,  0.3093,
#           1.4982,  0.4151,  1.5483, -1.3929,  0.0844],
#         [ 2.3289, -0.2430, -0.2310,  0.9688,  1.8609, -2.2459, -0.3837,  0.3093,
#           0.7902,  0.4151, -0.9103,  0.7179,  0.0844],
#         [ 1.5232, -0.2430, -0.2310,  0.2019, -0.4139, -0.0460, -0.3837,  0.3093,
#          -1.3336,  0.4151, -0.9103,  0.7179,  0.0844],
#         [-1.3334, -0.2430, -0.2310,  1.2244, -0.0347, -0.0460,  0.9164,  0.3093,
#          -1.3336,  0.4151, -0.2956, -1.3929, -1.2499],
#         [ 0.5710, -0.2430, -0.2310,  1.2244, -0.0347,  0.3469, -1.6837,  0.3093,
#           0.3183,  0.4151, -0.2956, -1.3929,  1.4187],
#         [-0.5277, -0.2430, -0.2310,  0.2019, -0.4139,  0.7397,  0.9164,  0.3093,
#           1.2622,  0.4151, -0.2956, -1.3929,  0.0844],
#         [ 1.4499, -0.2430, -0.2310, -0.3093,  1.1026, -0.0460, -0.3837, -3.3507,
#          -0.6257,  0.4151, -0.9103,  0.7179,  0.7516],
#         [ 0.1315, -0.2430, -0.2310,  0.9688,  1.8609,  0.7397, -0.3837,  0.3093,
#          -0.6257,  0.4151, -0.9103,  0.7179,  0.0844],
#         [ 0.0582,  5.3208, -0.2310, -0.3093,  1.1026,  4.5896, -0.3837,  0.3093,
#           0.7902,  0.4151, -0.9103,  0.7179,  0.0844],
#         [-0.7475, -0.2430, -0.2310,  0.2019, -0.4139, -0.0460,  0.9164,  0.0653,
#           0.3183, -2.9698, -0.2956,  0.7179,  2.0859],
#         [ 2.1824, -0.2430, -0.2310,  0.2019, -0.4139, -0.8317, -0.3837,  0.3093,
#           1.4982,  0.4151, -0.9103,  0.7179,  1.4187],
#         [ 0.9372, -0.2430, -0.2310,  0.2019, -0.4139, -0.0460, -0.3837,  0.3093,
#           1.2622,  0.4151, -0.9103,  0.7179,  0.0844],
#         [ 2.0359, -0.2430, -0.2310, -2.6099, -1.5512, -1.9316, -0.3837,  0.3093,
#           1.7342,  0.4151, -0.9103,  0.7179,  0.0844],
#         [-1.1869, -0.2430, -0.2310,  1.2244, -0.0347, -0.0460,  0.9164,  0.3093,
#           0.0823,  0.4151,  0.9336,  0.7179,  0.0844],
#         [-1.2602, -0.2430, -0.2310,  1.2244, -0.0347, -1.6174,  0.9164, -1.2767,
#           1.2622,  0.4151,  0.9336, -1.3929,  0.0844],
#         [-0.7475, -0.2430, -0.2310,  0.2019, -0.4139, -0.0460,  0.9164,  0.3093,
#          -0.8617, -4.0981, -0.2956,  0.7179,  0.0844],
#         [-0.0882, -0.2430, -0.2310,  1.2244, -0.0347, -2.2459,  0.9164,  0.3093,
#           0.3183,  0.4151, -0.2956,  0.7179, -1.2499],
#         [ 0.6442, -0.2430, -0.2310,  1.2244, -0.0347, -0.0460,  0.9164,  0.3093,
#           0.3183, -1.8415,  1.5483, -1.3929,  0.0844],
#         [ 1.3767, -0.2430, -0.2310, -1.0762, -1.9303, -0.0460, -0.3837,  0.3093,
#          -0.1537,  0.4151, -0.9103,  0.7179,  0.0844],
#         [-0.3080, -0.2430,  4.2087,  0.4576,  1.4818, -0.0460, -0.3837,  0.3093,
#           0.7902,  0.4151, -0.9103,  0.7179,  0.0844],
#         [ 0.7175, -0.2430, -0.2310, -1.3318, -2.3095, -0.4388, -1.6837,  0.3093,
#           0.3183,  0.4151,  1.5483, -1.3929,  0.0844],
#         [ 1.0837,  2.6041, -0.2310, -0.3093,  1.1026, -0.0460, -0.3837, -4.4487,
#          -0.6257,  0.4151, -0.9103,  0.7179,  0.7516],
#         [-0.3812, -0.2430, -0.2310,  0.2019, -0.4139, -0.0460, -1.6837,  0.3093,
#          -0.1537, -1.8415, -0.2956,  0.7179,  0.0844],
#         [ 1.1569, -0.2430, -0.2310,  0.2019, -0.4139,  0.7397, -0.3837,  0.3093,
#          -0.8617,  0.4151, -0.9103,  0.7179,  0.0844],
#         [ 0.3512, -0.2430, -0.2310,  0.9688,  1.8609, -0.0460,  0.9164,  0.3093,
#           0.7902,  0.4151, -0.2956, -1.3929,  0.0844],
#         [-1.4067, -0.2430, -0.2310, -0.5649,  0.3444, -1.2245,  0.9164,  0.3093,
#           1.4982,  0.4151,  0.9336, -1.3929,  0.0844],
#         [-0.4545, -0.2430, -0.2310,  0.4576,  1.4818, -0.0460,  0.9164, -3.1067,
#           0.7902,  0.4151, -0.2956, -1.3929, -1.2499]])

# %%
# convert val data to tensor for later
val_x_tensor = torch.tensor(X_val.values, dtype=torch.float)
val_y_tensor = torch.tensor(y_val.values, dtype=torch.float)

# %% [markdown]
# # Define training loop

# %% [markdown]
# <figure>
#   <img style="float: left;" src="./figures/train_loop.png" width="400"/>
# </figure>

# %%
def training_step(model, input_data, optimizer, loss_fn):
    # reset gradients of the optimizer
    optimizer.zero_grad()
    
    # unfold data
    x_batch, y_batch = input_data
    
    # get predictions
    y_pred_propa = model(x_batch)
    
    # calculate loss
    loss = loss_fn(y_pred_propa, y_batch)

    # compute gradients 
    loss.backward()
    
    # optimise network
    optimizer.step()
    
    # compute metrics for monitoring
    with torch.no_grad(): 
        y_pred = (y_pred_propa>0.5) * 1
        train_acc = torch.sum(y_pred == y_batch) / y_batch.shape[0]

    return loss.data.numpy(), train_acc.data.numpy()

# %%
def evaluation_step(model, input_data, loss_fn):
    # when we use torch.no_grad pytorch didnt store information
    # that is required to calculate gradients so is fasterr 
    with torch.no_grad(): 
        x_batch, y_batch = input_data
        y_pred_proba = model(x_batch)
        loss = loss_fn(y_pred_proba, y_batch)

        # compute metrics
        y_pred = (y_pred_proba>0.5) * 1
        acc = torch.sum(y_pred == y_batch) / y_batch.shape[0]
    return loss.data.numpy(), acc.data.numpy()

# %%
model = NeuralNetwork(num_input_features=13)

lr = 0.02
optimizer = torch.optim.SGD(model.parameters(), lr=lr)
loss_fn = torch.nn.BCELoss() # binary cross entropy

# %%
# parameters of the training loop
epochs = 400

# %%
# -------------------- Train  Loop----------------------------
train_history = []
val_history = []
for epoch in range(epochs): # iterate over epoch    

    # -------------------- 1. Training on each epoch ----------------------------
    accumulated_loss,accumulated_accuracy = 0, 0 # monitor loss and metrics during training
    for step, batch_data in enumerate(train_dataloader): # iterate over batch
        loss, accuracy = training_step(model,batch_data,optimizer,loss_fn) # train model using a single batch
        accumulated_loss = (step * accumulated_loss + loss)/(step+1)
        accumulated_accuracy =  (step * accumulated_accuracy + accuracy)/(step+1)
        
    # store the loss and the metrics at the end of each epoch
    train_history += [{"loss":accumulated_loss, "accuracy":accumulated_accuracy, "epoch": epoch}]
    
    # -------------------- 2. Monitor Error on Validation set ----------------------------
    val_loss, val_accuracy = evaluation_step(model, (val_x_tensor, val_y_tensor), loss_fn)
    val_history += [{"loss":val_loss, "accuracy":val_accuracy, "epoch": epoch}]
    if epoch % 10 == 0:
        print(f"Epoch {epoch}/{epochs}:  loss:{accumulated_loss:.3f}, accuracy-:{accumulated_accuracy:.3f}, val_loss:{val_loss:.3f}, val_accuracy->{val_accuracy:.3f}")
# Out:
# Epoch 0/400:  loss:0.462, accuracy-:0.784, val_loss:0.385, val_accuracy->0.823
# Epoch 10/400:  loss:0.334, accuracy-:0.842, val_loss:0.324, val_accuracy->0.846
# Epoch 20/400:  loss:0.327, accuracy-:0.847, val_loss:0.320, val_accuracy->0.844
# Epoch 30/400:  loss:0.322, accuracy-:0.848, val_loss:0.317, val_accuracy->0.847
# Epoch 40/400:  loss:0.318, accuracy-:0.850, val_loss:0.317, val_accuracy->0.850
# Epoch 50/400:  loss:0.314, accuracy-:0.851, val_loss:0.318, val_accuracy->0.843
# Epoch 60/400:  loss:0.311, accuracy-:0.853, val_loss:0.315, val_accuracy->0.848
# Epoch 70/400:  loss:0.308, accuracy-:0.854, val_loss:0.317, val_accuracy->0.847
# Epoch 80/400:  loss:0.305, accuracy-:0.855, val_loss:0.318, val_accuracy->0.847
# Epoch 90/400:  loss:0.302, accuracy-:0.856, val_loss:0.324, val_accuracy->0.839
# Epoch 100/400:  loss:0.299, accuracy-:0.857, val_loss:0.321, val_accuracy->0.844
# Epoch 110/400:  loss:0.297, accuracy-:0.858, val_loss:0.322, val_accuracy->0.844
# Epoch 120/400:  loss:0.294, accuracy-:0.859, val_loss:0.322, val_accuracy->0.841
# Epoch 130/400:  loss:0.292, accuracy-:0.860, val_loss:0.326, val_accuracy->0.838
# Epoch 140/400:  loss:0.290, accuracy-:0.860, val_loss:0.330, val_accuracy->0.839
# Epoch 150/400:  loss:0.287, accuracy-:0.862, val_loss:0.329, val_accuracy->0.840
# Epoch 160/400:  loss:0.286, accuracy-:0.862, val_loss:0.329, val_accuracy->0.846
# Epoch 170/400:  loss:0.283, accuracy-:0.864, val_loss:0.332, val_accuracy->0.841
# Epoch 180/400:  loss:0.282, accuracy-:0.864, val_loss:0.333, val_accuracy->0.837
# Epoch 190/400:  loss:0.279, accuracy-:0.867, val_loss:0.336, val_accuracy->0.836
# Epoch 200/400:  loss:0.279, accuracy-:0.867, val_loss:0.339, val_accuracy->0.830
# Epoch 210/400:  loss:0.275, accuracy-:0.869, val_loss:0.342, val_accuracy->0.839
# Epoch 220/400:  loss:0.274, accuracy-:0.867, val_loss:0.339, val_accuracy->0.831
# Epoch 230/400:  loss:0.272, accuracy-:0.868, val_loss:0.342, val_accuracy->0.830
# Epoch 240/400:  loss:0.271, accuracy-:0.868, val_loss:0.346, val_accuracy->0.838
# Epoch 250/400:  loss:0.270, accuracy-:0.872, val_loss:0.345, val_accuracy->0.835
# Epoch 260/400:  loss:0.268, accuracy-:0.870, val_loss:0.352, val_accuracy->0.832
# Epoch 270/400:  loss:0.266, accuracy-:0.871, val_loss:0.348, val_accuracy->0.835
# Epoch 280/400:  loss:0.265, accuracy-:0.872, val_loss:0.363, val_accuracy->0.837
# Epoch 290/400:  loss:0.263, accuracy-:0.873, val_loss:0.350, val_accuracy->0.834
# Epoch 300/400:  loss:0.261, accuracy-:0.875, val_loss:0.351, val_accuracy->0.839
# Epoch 310/400:  loss:0.259, accuracy-:0.875, val_loss:0.363, val_accuracy->0.831
# Epoch 320/400:  loss:0.258, accuracy-:0.877, val_loss:0.361, val_accuracy->0.835
# Epoch 330/400:  loss:0.256, accuracy-:0.878, val_loss:0.384, val_accuracy->0.829
# Epoch 340/400:  loss:0.255, accuracy-:0.879, val_loss:0.368, val_accuracy->0.840
# Epoch 350/400:  loss:0.255, accuracy-:0.877, val_loss:0.365, val_accuracy->0.829
# Epoch 360/400:  loss:0.252, accuracy-:0.879, val_loss:0.371, val_accuracy->0.827
# Epoch 370/400:  loss:0.250, accuracy-:0.880, val_loss:0.365, val_accuracy->0.839
# Epoch 380/400:  loss:0.248, accuracy-:0.881, val_loss:0.377, val_accuracy->0.832
# Epoch 390/400:  loss:0.244, accuracy-:0.882, val_loss:0.393, val_accuracy->0.837

# %%
val_history_df = pd.DataFrame(val_history)
train_history_df = pd.DataFrame(train_history)

# %% [markdown]
# # Learning Curves and Overfitting
#
# **Overfitting** refers to the phenomenon when our model performs well on the training set but exhibits poor performance on the testing set.
#
# Since neural networks have a large number of parameters, they are prone to overfitting the training data, resulting in bad performance during testing.
# This occurs when the model exploits pattern between the data (X) and the labels (Y) that is not in the testing data.
#
# One way to monitor the performance of our algorithm is by using learning curves.
#
# Learning curves track the performance of the model during training by measuring various metrics at regular optimization steps.
# Learning curves provide valuable insights into the model's behavior, allowing us to detect overfitting.
#
#
# To identify overfitting, we typically compare the learning curves of the training and validation sets.

# %% [markdown]
# <figure>
#   <img style="float: left;" src="./figures/epoch-error-curve-fitting.png" width="400"/>
# </figure>

# %% [markdown]
# For example, in the plot above, we can observe the learning curves of the training and validation sets during training. At the beginning of training, the model minimizes the loss on both the training and validation sets. However, after several epochs, you can see that the validation error starts to increase while the training loss continues to decrease. This indicates that the model is learning patterns specific to the training set that do not generalize well to the validation set, leading to loss increases.

# %%
plt.figure()
plt.plot(train_history_df["epoch"],train_history_df["loss"], label = "Training set")
plt.plot(val_history_df["epoch"],val_history_df["loss"], label = "Validation set")
plt.title("Learning Curve")
plt.ylabel("Cross Entropy Loss")
plt.xlabel("Epoch")
plt.legend()

# %%
plt.figure()
plt.plot(train_history_df["epoch"],train_history_df["accuracy"], label = "Training set")
plt.plot(val_history_df["epoch"],val_history_df["accuracy"], label = "Validation set")
plt.title("Learning Curve")
plt.ylabel("Accuracy")
plt.xlabel("Epoch")
plt.legend()

# %% [markdown]
# # Assignment 6
#
# In the 6th assignment we will see the effect of different techniques to reduce overfitting when training a neural network.

# %% [markdown]
# # A. Early stopping
# Early stopping is an optimization technique used to reduce overfitting without compromising on model accuracy. The main idea behind early stopping is to stop training before a model starts to over-fit.
#
#
# To use early stopping, you watch for the validation loss. If it stops improving for several consecutive epochs , indicated by the "patient" parameter, you stop training.
#
# **Steps:**
#    1) Implement Early Stopping.
#    2) Train your model using early stopping.
#    3) Check different patient parameters. For example, you can set patient = {5 , 100}. Can the patient parameter affect the coverage of your network?

# %% [markdown]
# # Solution

# %%
# -------------------- Train  Loop----------------------------

consecutive_non_improving_epochs = 0
patient = 5

train_history = []
val_history = []
for epoch in range(epochs): # iterate over epoch    

    #print(consecutive_non_improving_epochs)

    # -------------------- 1. Training on each epoch ----------------------------
    accumulated_loss,accumulated_accuracy = 0, 0 # monitor loss and metrics during training
    for step, batch_data in enumerate(train_dataloader): # iterate over batch
        loss, accuracy = training_step(model,batch_data,optimizer,loss_fn) # train model using a single batch
        accumulated_loss = (step * accumulated_loss + loss)/(step+1)
        accumulated_accuracy =  (step * accumulated_accuracy + accuracy)/(step+1)
        
    # store the loss and the metrics at the end of each epoch
    train_history += [{"loss":accumulated_loss, "accuracy":accumulated_accuracy, "epoch": epoch}]
    
    # -------------------- 2. Monitor Error on Validation set ----------------------------
    val_loss, val_accuracy = evaluation_step(model, (val_x_tensor, val_y_tensor), loss_fn)
    val_history += [{"loss":val_loss, "accuracy":val_accuracy, "epoch": epoch}]
    if epoch % 10 == 0:
        print(f"Epoch {epoch}/{epochs}:  loss:{accumulated_loss:.3f}, accuracy:{accumulated_accuracy:.3f}, val_loss:{val_loss:.3f}, val_accuracy->{val_accuracy:.3f}")

    if val_history[epoch-1]["loss"] < val_loss and epoch > 0:
        consecutive_non_improving_epochs += 1

    else:
        consecutive_non_improving_epochs = 0

    if consecutive_non_improving_epochs >= patient:
        print(f"Early stopping after {epoch} epochs without improvement.")
        break
# Out:
# 0
# Epoch 0/400:  loss:0.245, accuracy:0.882, val_loss:0.379, val_accuracy->0.837
# 0
# 1
# 2
# 0
# 1
# 0
# 1
# 0
# 0
# 1
# Epoch 10/400:  loss:0.245, accuracy:0.881, val_loss:0.379, val_accuracy->0.836
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 0
# 1
# 2
# Epoch 20/400:  loss:0.244, accuracy:0.882, val_loss:0.384, val_accuracy->0.824
# 0
# 1
# 2
# 0
# 1
# 0
# 1
# 2
# 3
# 0
# Epoch 30/400:  loss:0.242, accuracy:0.882, val_loss:0.386, val_accuracy->0.819
# 1
# 2
# 0
# 1
# 0
# 0
# 0
# 1
# 0
# 1
# Epoch 40/400:  loss:0.239, accuracy:0.887, val_loss:0.392, val_accuracy->0.827
# 2
# 0
# 1
# 0
# 0
# 1
# 0
# 0
# 1
# 0
# Epoch 50/400:  loss:0.239, accuracy:0.885, val_loss:0.390, val_accuracy->0.829
# 0
# 1
# 0
# 0
# 1
# 0
# 1
# 2
# 0
# 1
# Epoch 60/400:  loss:0.237, accuracy:0.885, val_loss:0.396, val_accuracy->0.834
# 0
# 0
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# Epoch 70/400:  loss:0.236, accuracy:0.886, val_loss:0.406, val_accuracy->0.815
# 2
# 0
# 0
# 1
# 0
# 0
# 1
# 0
# 0
# 0
# Epoch 80/400:  loss:0.235, accuracy:0.889, val_loss:0.402, val_accuracy->0.833
# 1
# 0
# 0
# 1
# 0
# 0
# 1
# 0
# 0
# 1
# Epoch 90/400:  loss:0.234, accuracy:0.889, val_loss:0.392, val_accuracy->0.831
# 0
# 1
# 0
# 1
# 2
# 0
# 1
# 0
# 1
# 2
# Epoch 100/400:  loss:0.232, accuracy:0.889, val_loss:0.401, val_accuracy->0.836
# 0
# 0
# 1
# 0
# 0
# 0
# 1
# 2
# 0
# 1
# Epoch 110/400:  loss:0.230, accuracy:0.888, val_loss:0.407, val_accuracy->0.829
# 0
# 1
# 0
# 1
# 0
# 0
# 0
# 0
# 1
# 0
# Epoch 120/400:  loss:0.229, accuracy:0.890, val_loss:0.419, val_accuracy->0.820
# 1
# 0
# 0
# 1
# 0
# 0
# 1
# 2
# 3
# 0
# Epoch 130/400:  loss:0.229, accuracy:0.890, val_loss:0.409, val_accuracy->0.829
# 1
# 2
# 0
# 1
# 0
# 0
# 0
# 1
# 2
# 0
# Epoch 140/400:  loss:0.228, accuracy:0.888, val_loss:0.411, val_accuracy->0.824
# 0
# 0
# 1
# 0
# 1
# 0
# 0
# 1
# 0
# 0
# Epoch 150/400:  loss:0.226, accuracy:0.892, val_loss:0.431, val_accuracy->0.834
# 1
# 0
# 1
# 0
# 1
# 2
# 3
# 0
# 0
# 1
# Epoch 160/400:  loss:0.223, accuracy:0.893, val_loss:0.442, val_accuracy->0.810
# 2
# 0
# 0
# 1
# 2
# 0
# 0
# 0
# 0
# 1
# Epoch 170/400:  loss:0.223, accuracy:0.893, val_loss:0.435, val_accuracy->0.812
# 2
# 0
# 1
# 2
# 0
# 1
# 0
# 0
# 1
# 0
# Epoch 180/400:  loss:0.222, accuracy:0.894, val_loss:0.426, val_accuracy->0.833
# 1
# 0
# 1
# 0
# 1
# 2
# 3
# 0
# 0
# 1
# Epoch 190/400:  loss:0.221, accuracy:0.893, val_loss:0.432, val_accuracy->0.832
# 0
# 1
# 0
# 0
# 1
# 0
# 0
# 1
# 2
# 0
# Epoch 200/400:  loss:0.221, accuracy:0.893, val_loss:0.519, val_accuracy->0.787
# 1
# 0
# 0
# 1
# 0
# 1
# 2
# 0
# 0
# 1
# Epoch 210/400:  loss:0.220, accuracy:0.896, val_loss:0.428, val_accuracy->0.823
# 0
# 0
# 0
# 1
# 0
# 0
# 1
# 2
# 3
# 4
# Epoch 220/400:  loss:0.217, accuracy:0.896, val_loss:0.454, val_accuracy->0.836
# Early stopping after 220 epochs without improvement.

# %% [markdown]
# # B. Reduce the Size of the Network
#
# The capacity (total number of parameters) of the model affects the training process. If the parameters are too numerous compared to the difficulty of the underlying problem, it's very easy to overfit.
#
# To address this issue, reduce the total number of parameters in the model by decreasing the number of units in each layer, and then comment on the results.
#
# **Steps:**
# 1. Reduce the size of the network by lowering the number of units. You can use 60 units for the first layer and 20 units for the second one.
# 2. Train your model without early stopping.
# 3. Compare the learning curve of this model with the learning curve of the larger model we trained without early stopping (used in section Learning Curves and Overfitting).

# %% [markdown]
# # Solution

# %%
class SmallerNeuralNetwork(torch.nn.Module):
    """
    Simple two layer neural network for regression
    """
    def __init__(self, num_input_features):
        super().__init__()
        
        # layer 1
        layer_1_units = 60
        self.layer_1 = torch.nn.Linear(in_features=num_input_features,
                                       out_features=layer_1_units)
        self.activation_1 = torch.nn.ReLU()
        
        # layer  2
        layer_2_units = 20
        self.layer_2 = torch.nn.Linear(in_features=layer_1_units,
                                       out_features=layer_2_units)
        self.activation_2 = torch.nn.ReLU()
        
        # layer output layer
        self.out_layer = torch.nn.Linear(in_features=layer_2_units,
                                         out_features=1)
        self.out_activation= torch.nn.Sigmoid()

    def forward(self, x):
        x_1 = self.activation_1( self.layer_1( x ) )
        x_2 = self.activation_2( self.layer_2( x_1 ) )
        output = self.out_activation(self.out_layer(x_2))
        return output

# %%
small_model = SmallerNeuralNetwork(num_input_features=13)

lr = 0.02
optimizer = torch.optim.SGD(small_model.parameters(), lr=lr)
loss_fn = torch.nn.BCELoss() # binary cross entropy

epochs = 400

# %%
# -------------------- Train  Loop----------------------------
small_train_history = []
small_val_history = []
for epoch in range(epochs): # iterate over epoch    

    # -------------------- 1. Training on each epoch ----------------------------
    accumulated_loss,accumulated_accuracy = 0, 0 # monitor loss and metrics during training
    for step, batch_data in enumerate(train_dataloader): # iterate over batch
        loss, accuracy = training_step(small_model,batch_data,optimizer,loss_fn) # train model using a single batch
        accumulated_loss = (step * accumulated_loss + loss)/(step+1)
        accumulated_accuracy =  (step * accumulated_accuracy + accuracy)/(step+1)
        
    # store the loss and the metrics at the end of each epoch
    small_train_history += [{"loss":accumulated_loss, "accuracy":accumulated_accuracy, "epoch": epoch}]
    
    # -------------------- 2. Monitor Error on Validation set ----------------------------
    val_loss, val_accuracy = evaluation_step(small_model, (val_x_tensor, val_y_tensor), loss_fn)
    small_val_history += [{"loss":val_loss, "accuracy":val_accuracy, "epoch": epoch}]
    if epoch % 10 == 0:
        print(f"Epoch {epoch}/{epochs}:  loss:{accumulated_loss:.3f}, accuracy:{accumulated_accuracy:.3f}, val_loss:{val_loss:.3f}, val_accuracy->{val_accuracy:.3f}")
# Out:
# Epoch 0/400:  loss:0.525, accuracy:0.742, val_loss:0.435, val_accuracy->0.792
# Epoch 10/400:  loss:0.337, accuracy:0.842, val_loss:0.328, val_accuracy->0.843
# Epoch 20/400:  loss:0.330, accuracy:0.846, val_loss:0.322, val_accuracy->0.842
# Epoch 30/400:  loss:0.325, accuracy:0.848, val_loss:0.318, val_accuracy->0.846
# Epoch 40/400:  loss:0.322, accuracy:0.847, val_loss:0.316, val_accuracy->0.846
# Epoch 50/400:  loss:0.319, accuracy:0.849, val_loss:0.315, val_accuracy->0.849
# Epoch 60/400:  loss:0.317, accuracy:0.849, val_loss:0.314, val_accuracy->0.852
# Epoch 70/400:  loss:0.315, accuracy:0.850, val_loss:0.316, val_accuracy->0.847
# Epoch 80/400:  loss:0.313, accuracy:0.852, val_loss:0.316, val_accuracy->0.849
# Epoch 90/400:  loss:0.312, accuracy:0.851, val_loss:0.316, val_accuracy->0.845
# Epoch 100/400:  loss:0.310, accuracy:0.852, val_loss:0.319, val_accuracy->0.845
# Epoch 110/400:  loss:0.309, accuracy:0.850, val_loss:0.318, val_accuracy->0.846
# Epoch 120/400:  loss:0.307, accuracy:0.853, val_loss:0.320, val_accuracy->0.845
# Epoch 130/400:  loss:0.306, accuracy:0.853, val_loss:0.318, val_accuracy->0.847
# Epoch 140/400:  loss:0.305, accuracy:0.855, val_loss:0.323, val_accuracy->0.842
# Epoch 150/400:  loss:0.304, accuracy:0.854, val_loss:0.320, val_accuracy->0.845
# Epoch 160/400:  loss:0.303, accuracy:0.855, val_loss:0.322, val_accuracy->0.843
# Epoch 170/400:  loss:0.302, accuracy:0.855, val_loss:0.320, val_accuracy->0.844
# Epoch 180/400:  loss:0.301, accuracy:0.857, val_loss:0.323, val_accuracy->0.843
# Epoch 190/400:  loss:0.300, accuracy:0.857, val_loss:0.325, val_accuracy->0.846
# Epoch 200/400:  loss:0.300, accuracy:0.858, val_loss:0.323, val_accuracy->0.847
# Epoch 210/400:  loss:0.299, accuracy:0.857, val_loss:0.323, val_accuracy->0.846
# Epoch 220/400:  loss:0.299, accuracy:0.857, val_loss:0.328, val_accuracy->0.842
# Epoch 230/400:  loss:0.298, accuracy:0.857, val_loss:0.327, val_accuracy->0.843
# Epoch 240/400:  loss:0.297, accuracy:0.856, val_loss:0.327, val_accuracy->0.842
# Epoch 250/400:  loss:0.297, accuracy:0.858, val_loss:0.324, val_accuracy->0.846
# Epoch 260/400:  loss:0.296, accuracy:0.859, val_loss:0.327, val_accuracy->0.840
# Epoch 270/400:  loss:0.295, accuracy:0.860, val_loss:0.330, val_accuracy->0.843
# Epoch 280/400:  loss:0.295, accuracy:0.859, val_loss:0.329, val_accuracy->0.841
# Epoch 290/400:  loss:0.295, accuracy:0.860, val_loss:0.328, val_accuracy->0.846
# Epoch 300/400:  loss:0.294, accuracy:0.861, val_loss:0.326, val_accuracy->0.846
# Epoch 310/400:  loss:0.293, accuracy:0.861, val_loss:0.331, val_accuracy->0.839
# Epoch 320/400:  loss:0.293, accuracy:0.859, val_loss:0.328, val_accuracy->0.843
# Epoch 330/400:  loss:0.292, accuracy:0.860, val_loss:0.329, val_accuracy->0.842
# Epoch 340/400:  loss:0.292, accuracy:0.860, val_loss:0.335, val_accuracy->0.841
# Epoch 350/400:  loss:0.292, accuracy:0.860, val_loss:0.327, val_accuracy->0.838
# Epoch 360/400:  loss:0.291, accuracy:0.861, val_loss:0.333, val_accuracy->0.839
# Epoch 370/400:  loss:0.291, accuracy:0.861, val_loss:0.331, val_accuracy->0.838
# Epoch 380/400:  loss:0.291, accuracy:0.861, val_loss:0.332, val_accuracy->0.843
# Epoch 390/400:  loss:0.290, accuracy:0.861, val_loss:0.328, val_accuracy->0.837

# %%
small_val_history_df = pd.DataFrame(small_val_history)
small_train_history_df = pd.DataFrame(small_train_history)

# %%
plt.figure()
plt.plot(small_train_history_df["epoch"],small_train_history_df["loss"], label = "Small training set")
plt.plot(small_val_history_df["epoch"],small_val_history_df["loss"], label = "Small validation set")
plt.plot(train_history_df["epoch"],train_history_df["loss"], label = "Large training set")
plt.plot(val_history_df["epoch"],val_history_df["loss"], label = "Large validation set")
plt.title("Learning Curve")
plt.ylabel("Cross Entropy Loss")
plt.xlabel("Epoch")
plt.legend()

# %%
plt.figure()
plt.plot(small_train_history_df["epoch"],small_train_history_df["accuracy"], label = "Small training set")
plt.plot(small_val_history_df["epoch"],small_val_history_df["accuracy"], label = "Small validation set")
plt.plot(train_history_df["epoch"],train_history_df["accuracy"], label = "Large training set")
plt.plot(val_history_df["epoch"],val_history_df["accuracy"], label = "Large validation set")
plt.title("Learning Curve")
plt.ylabel("Accuracy")
plt.xlabel("Epoch")
plt.legend()

# %% [markdown]
# # C. Weight Regularization
#
# Weight Regularization is another very famous technique to reduce overfitting.
# The concept of regularization is to add a constraint in the loss function to keep the weights of the model small.
#
# To get the intuition, weights regularization discourages the model from fitting the training data too closely and forces it to focus on the most important features. By constraining the model's weights, it can generalize better to new data because it's less likely to memorize the training examples and is more likely to capture underlying patterns and relationships in the data.
#
# A very famous and easy regularization is the L2-regularization where we modify the loss function as follows:
#
# $$ \text{Total Loss} = \mathbb{E}_{x,y \sim P_{data}} \left[ loss(f_w(x),y) \right] + \lambda \sum_{j=1}^{p} w_j^2 $$
#
# Where $\lambda$ is a scaling paramter, $loss$ in the loss function, $w$ the parameters of the model. Finally, $p$ indicates the set of different parameters
#
# In pytorch is very easy to apply L2-regularization. You can do that using the weight_decay ($\lambda$) parameter of the optimizer class.

# %% [markdown]
# ```python
# torch.optim.SGD(model.parameters(), lr=lr, weight_decay=λ)

# %% [markdown]
# **Steps :**
# 1) Use $\lambda = 0.01$ and train your model using L2 regularization, as explained before.
# Use the model architeture with the more paramter and dont aply early stoping to see the effect.
# 3) Compare with the initial training without early stoping (used in section Learning Curves and Overfitting) and comment on the results.

# %% [markdown]
# # Solution

# %%
class RegularizedNeuralNetwork(torch.nn.Module):
    """
    Simple two layer neural network for regression
    """
    def __init__(self, num_input_features):
        super().__init__()
        
        # layer 1
        layer_1_units = 200
        self.layer_1 = torch.nn.Linear(in_features=num_input_features,
                                       out_features=layer_1_units)
        self.activation_1 = torch.nn.ReLU()
        
        # layer  2
        layer_2_units = 100
        self.layer_2 = torch.nn.Linear(in_features=layer_1_units,
                                       out_features=layer_2_units)
        self.activation_2 = torch.nn.ReLU()
        
        # layer output layer
        self.out_layer = torch.nn.Linear(in_features=layer_2_units,
                                         out_features=1)
        self.out_activation= torch.nn.Sigmoid()

    def forward(self, x):
        x_1 = self.activation_1( self.layer_1( x ) )
        x_2 = self.activation_2( self.layer_2( x_1 ) )
        output = self.out_activation(self.out_layer(x_2))
        return output

# %%
regularized_model = RegularizedNeuralNetwork(num_input_features=13)

lr = 0.02
λ = 0.01
optimizer = torch.optim.SGD(regularized_model.parameters(), lr=lr, weight_decay=λ)
loss_fn = torch.nn.BCELoss() # binary cross entropy

epochs = 400

# %%
# -------------------- Train  Loop----------------------------
regularized_train_history = []
regularized_val_history = []
for epoch in range(epochs): # iterate over epoch    

    # -------------------- 1. Training on each epoch ----------------------------
    accumulated_loss,accumulated_accuracy = 0, 0 # monitor loss and metrics during training
    for step, batch_data in enumerate(train_dataloader): # iterate over batch
        loss, accuracy = training_step(regularized_model,batch_data,optimizer,loss_fn) # train model using a single batch
        accumulated_loss = (step * accumulated_loss + loss)/(step+1)
        accumulated_accuracy =  (step * accumulated_accuracy + accuracy)/(step+1)
        
    # store the loss and the metrics at the end of each epoch
    regularized_train_history += [{"loss":accumulated_loss, "accuracy":accumulated_accuracy, "epoch": epoch}]
    
    # -------------------- 2. Monitor Error on Validation set ----------------------------
    val_loss, val_accuracy = evaluation_step(regularized_model, (val_x_tensor, val_y_tensor), loss_fn)
    regularized_val_history += [{"loss":val_loss, "accuracy":val_accuracy, "epoch": epoch}]
    if epoch % 10 == 0:
        print(f"Epoch {epoch}/{epochs}:  loss:{accumulated_loss:.3f}, accuracy:{accumulated_accuracy:.3f}, val_loss:{val_loss:.3f}, val_accuracy->{val_accuracy:.3f}")
# Out:
# Epoch 0/400:  loss:0.459, accuracy:0.791, val_loss:0.390, val_accuracy->0.820
# Epoch 10/400:  loss:0.343, accuracy:0.839, val_loss:0.334, val_accuracy->0.839
# Epoch 20/400:  loss:0.339, accuracy:0.841, val_loss:0.332, val_accuracy->0.841
# Epoch 30/400:  loss:0.339, accuracy:0.841, val_loss:0.332, val_accuracy->0.841
# Epoch 40/400:  loss:0.339, accuracy:0.841, val_loss:0.332, val_accuracy->0.839
# Epoch 50/400:  loss:0.338, accuracy:0.841, val_loss:0.331, val_accuracy->0.840
# Epoch 60/400:  loss:0.338, accuracy:0.841, val_loss:0.331, val_accuracy->0.841
# Epoch 70/400:  loss:0.338, accuracy:0.841, val_loss:0.331, val_accuracy->0.842
# Epoch 80/400:  loss:0.338, accuracy:0.841, val_loss:0.331, val_accuracy->0.840
# Epoch 90/400:  loss:0.338, accuracy:0.841, val_loss:0.331, val_accuracy->0.841
# Epoch 100/400:  loss:0.338, accuracy:0.839, val_loss:0.331, val_accuracy->0.840
# Epoch 110/400:  loss:0.338, accuracy:0.840, val_loss:0.331, val_accuracy->0.840
# Epoch 120/400:  loss:0.338, accuracy:0.841, val_loss:0.332, val_accuracy->0.839
# Epoch 130/400:  loss:0.338, accuracy:0.842, val_loss:0.332, val_accuracy->0.838
# Epoch 140/400:  loss:0.338, accuracy:0.841, val_loss:0.331, val_accuracy->0.843
# Epoch 150/400:  loss:0.338, accuracy:0.842, val_loss:0.331, val_accuracy->0.840
# Epoch 160/400:  loss:0.338, accuracy:0.841, val_loss:0.331, val_accuracy->0.839
# Epoch 170/400:  loss:0.338, accuracy:0.840, val_loss:0.331, val_accuracy->0.840
# Epoch 180/400:  loss:0.338, accuracy:0.841, val_loss:0.331, val_accuracy->0.843
# Epoch 190/400:  loss:0.338, accuracy:0.841, val_loss:0.331, val_accuracy->0.840
# Epoch 200/400:  loss:0.338, accuracy:0.841, val_loss:0.331, val_accuracy->0.843
# Epoch 210/400:  loss:0.338, accuracy:0.841, val_loss:0.331, val_accuracy->0.842
# Epoch 220/400:  loss:0.338, accuracy:0.842, val_loss:0.331, val_accuracy->0.840
# Epoch 230/400:  loss:0.338, accuracy:0.842, val_loss:0.331, val_accuracy->0.841
# Epoch 240/400:  loss:0.338, accuracy:0.841, val_loss:0.331, val_accuracy->0.841
# Epoch 250/400:  loss:0.338, accuracy:0.840, val_loss:0.331, val_accuracy->0.842
# Epoch 260/400:  loss:0.338, accuracy:0.841, val_loss:0.330, val_accuracy->0.842
# Epoch 270/400:  loss:0.338, accuracy:0.842, val_loss:0.331, val_accuracy->0.841
# Epoch 280/400:  loss:0.338, accuracy:0.841, val_loss:0.332, val_accuracy->0.839
# Epoch 290/400:  loss:0.338, accuracy:0.841, val_loss:0.330, val_accuracy->0.842
# Epoch 300/400:  loss:0.338, accuracy:0.841, val_loss:0.331, val_accuracy->0.841
# Epoch 310/400:  loss:0.338, accuracy:0.841, val_loss:0.331, val_accuracy->0.840
# Epoch 320/400:  loss:0.338, accuracy:0.841, val_loss:0.331, val_accuracy->0.841
# Epoch 330/400:  loss:0.338, accuracy:0.841, val_loss:0.331, val_accuracy->0.842
# Epoch 340/400:  loss:0.338, accuracy:0.841, val_loss:0.331, val_accuracy->0.842
# Epoch 350/400:  loss:0.338, accuracy:0.841, val_loss:0.331, val_accuracy->0.839
# Epoch 360/400:  loss:0.338, accuracy:0.840, val_loss:0.330, val_accuracy->0.842
# Epoch 370/400:  loss:0.338, accuracy:0.841, val_loss:0.331, val_accuracy->0.839
# Epoch 380/400:  loss:0.338, accuracy:0.841, val_loss:0.332, val_accuracy->0.838
# Epoch 390/400:  loss:0.338, accuracy:0.841, val_loss:0.331, val_accuracy->0.839

# %%
regularized_val_history_df = pd.DataFrame(regularized_val_history)
regularized_train_history_df = pd.DataFrame(regularized_train_history)

# %%
plt.figure()
plt.plot(regularized_train_history_df["epoch"],regularized_train_history_df["loss"], label = "Regularized training set")
plt.plot(regularized_val_history_df["epoch"],regularized_val_history_df["loss"], label = "Regularized validation set")
plt.plot(train_history_df["epoch"],train_history_df["loss"], label = "Large training set")
plt.plot(val_history_df["epoch"],val_history_df["loss"], label = "Large validation set")
plt.title("Learning Curve")
plt.ylabel("Cross Entropy Loss")
plt.xlabel("Epoch")
plt.legend()

# %%
plt.figure()
plt.plot(regularized_train_history_df["epoch"],regularized_train_history_df["accuracy"], label = "Regularized training set")
plt.plot(regularized_val_history_df["epoch"],regularized_val_history_df["accuracy"], label = "Regularized validation set")
plt.plot(train_history_df["epoch"],train_history_df["accuracy"], label = "Large training set")
plt.plot(val_history_df["epoch"],val_history_df["accuracy"], label = "Large validation set")
plt.title("Learning Curve")
plt.ylabel("Accuracy")
plt.xlabel("Epoch")
plt.legend()
